# %% [markdown]
# #Machine Learning Prototype

# %% [markdown]
# This notebook takes all the data collected, and compares different machine learning algorithms to determine which one is the best. This could not have been possible without using Payton Soicher's machine learning writeup as a reference. You can find it here: https://towardsdatascience.com/can-you-accurately-predict-mlb-games-based-on-home-and-away-records-8a9a919bad29
#
# This model looked at the head to head matchup to see if a team at home would win.

# %%
#imports
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import xgboost as xgb
from constants import ID_TO_NAME

# %%
#getting the schedule data and team stats
df = pd.read_csv("data2019.csv")
stats = pd.read_csv("stats.csv")

#setting index to team name for easier refrencing
stats = stats.set_index("Team Name")

# %%
#filtering out the data
colums = ["stage", "away id","away","away score", "home id", "home score", "home", "winner", "winner id", "winner label",
         "Map 1 Name", "Map 1 Type", "Map 1 Away Points", "Map 1 Home Points", "Map 1 Winner",
        "Map 2 Name", "Map 2 Type", "Map 2 Away Points", "Map 2 Home Points", "Map 2 Winner",
        "Map 3 Name", "Map 3 Type", "Map 3 Away Points", "Map 3 Home Points", "Map 3 Winner", 
        "Map 4 Name", "Map 4 Type", "Map 4 Away Points", "Map 4 Home Points", "Map 4 Winner",
        "Map 5 Name", "Map 5 Type", "Map 5 Away Points", "Map 5 Home Points", "Map 5 Winner",
         ]

sdf = df[colums]

# %% [markdown]
# With the team stats, I had collected both map specific stats, as well as general map type stats. For now, I am sticking to map type stats, with the goal being to collect map specific stats based on what maps are being played.

# %%
#filter out to map type stats
import itertools
cols = ["Points Earned", "Points Lost", "Points Differential", "Points Differential Rank", "True Win %", "Map Potential %", "Map Potential % Rank"]
types = ["Average Assault", "Average Control", "Average Hybrid", "Average Escort"]
columns = []
for i in types:
    columns.append([i + " " + j for j in cols])

columns = list(itertools.chain.from_iterable(columns))
sta = stats[columns]
sta
# Out:
#                         Average Assault Points Earned  \
# Team Name
# Atlanta Reign                                  2.3416
# Boston Uprising                                2.3466
# Chengdu Hunters                                2.2584
# Dallas Fuel                                    2.2092
# Florida Mayhem                                 2.4058
# Guangzhou Charge                               2.2058
# Hangzhou Spark                                 2.1294
# Houston Outlaws                                1.7492
# London Spitfire                                2.2620
# Los Angeles Gladiators                         2.1894
# Los Angeles Valiant                            2.1220
# New York Excelsior                             2.1624
# Paris Eternal                                  1.9966
# Philadelphia Fusion                            2.3196
# San Francisco Shock                            2.7654
# Seoul Dynasty                                  2.3574
# Shanghai Dragons                               2.6066
# Toronto Defiant                                1.9016
# Vancouver Titans                               2.1022
# Washington Justice                             1.5908
#
#                         Average Assault Points Lost  \
# Team Name
# Atlanta Reign                                2.1500
# Boston Uprising                              2.6266
# Chengdu Hunters                              2.3084
# Dallas Fuel                                  2.7736
# Florida Mayhem                               2.6104
# Guangzhou Charge                             2.1962
# Hangzhou Spark                               2.0376
# Houston Outlaws                              2.0878
# London Spitfire                              2.0416
# Los Angeles Gladiators                       1.9448
# Los Angeles Valiant                          2.1752
# New York Excelsior                           1.9222
# Paris Eternal                                2.3534
# Philadelphia Fusion                          2.6138
# San Francisco Shock                          1.8650
# Seoul Dynasty                                2.2094
# Shanghai Dragons                             2.5466
# Toronto Defiant                              2.2484
# Vancouver Titans                             1.8444
# Washington Justice                           1.9764
#
#                         Average Assault Points Differential  \
# Team Name
# Atlanta Reign                                        0.1916
# Boston Uprising                                     -0.2800
# Chengdu Hunters                                     -0.0500
# Dallas Fuel                                         -0.5644
# Florida Mayhem                                      -0.2046
# Guangzhou Charge                                     0.0096
# Hangzhou Spark                                       0.0918
# Houston Outlaws                                     -0.3386
# London Spitfire                                      0.2204
# Los Angeles Gladiators                               0.2446
# Los Angeles Valiant                                 -0.0532
# New York Excelsior                                   0.2402
# Paris Eternal                                       -0.3568
# Philadelphia Fusion                                 -0.2942
# San Francisco Shock                                  0.9004
# Seoul Dynasty                                        0.1480
# Shanghai Dragons                                     0.0600
# Toronto Defiant                                     -0.3468
# Vancouver Titans                                     0.2578
# Washington Justice                                  -0.3856
#
#                         Average Assault Points Differential Rank  \
# Team Name
# Atlanta Reign                                                6.0
# Boston Uprising                                             14.0
# Chengdu Hunters                                             11.0
# Dallas Fuel                                                 20.0
# Florida Mayhem                                              13.0
# Guangzhou Charge                                            10.0
# Hangzhou Spark                                               8.0
# Houston Outlaws                                             16.0
# London Spitfire                                              5.0
# Los Angeles Gladiators                                       3.0
# Los Angeles Valiant                                         12.0
# New York Excelsior                                           4.0
# Paris Eternal                                               18.0
# Philadelphia Fusion                                         15.0
# San Francisco Shock                                          1.0
# Seoul Dynasty                                                7.0
# Shanghai Dragons                                             9.0
# Toronto Defiant                                             17.0
# Vancouver Titans                                             2.0
# Washington Justice                                          19.0
#
#                         Average Assault True Win %  \
# Team Name
# Atlanta Reign                              55.0000
# Boston Uprising                            33.5000
# Chengdu Hunters                            45.8334
# Dallas Fuel                                28.2858
# Florida Mayhem                             38.3332
# Guangzhou Charge                           50.6192
# Hangzhou Spark                             56.8572
# Houston Outlaws                            36.0000
# London Spitfire                            57.6786
# Los Angeles Gladiators                     57.1516
# Los Angeles Valiant                        46.0834
# New York Excelsior                         59.9884
# Paris Eternal                              36.7500
# Philadelphia Fusion                        36.9446
# San Francisco Shock                        87.6882
# Seoul Dynasty                              53.3056
# Shanghai Dragons                           55.0000
# Toronto Defiant                            38.8334
# Vancouver Titans                           64.6668
# Washington Justice                         41.0714
#
#                         Average Assault Map Potential %  \
# Team Name
# Atlanta Reign                                    0.7510
# Boston Uprising                                  0.7144
# Chengdu Hunters                                  0.7890
# Dallas Fuel                                      0.6474
# Florida Mayhem                                   0.7464
# Guangzhou Charge                                 0.7120
# Hangzhou Spark                                   0.7934
# Houston Outlaws                                  0.5490
# London Spitfire                                  0.7848
# Los Angeles Gladiators                           0.8010
# Los Angeles Valiant                              0.7910
# New York Excelsior                               0.8234
# Paris Eternal                                    0.6822
# Philadelphia Fusion                              0.7500
# San Francisco Shock                              0.9292
# Seoul Dynasty                                    0.7998
# Shanghai Dragons                                 0.7742
# Toronto Defiant                                  0.6884
# Vancouver Titans                                 0.8288
# Washington Justice                               0.6902
#
#                         Average Assault Map Potential % Rank  \
# Team Name
# Atlanta Reign                                           11.0
# Boston Uprising                                         14.0
# Chengdu Hunters                                          8.0
# Dallas Fuel                                             19.0
# Florida Mayhem                                          13.0
# Guangzhou Charge                                        15.0
# Hangzhou Spark                                           6.0
# Houston Outlaws                                         20.0
# London Spitfire                                          9.0
# Los Angeles Gladiators                                   4.0
# Los Angeles Valiant                                      7.0
# New York Excelsior                                       3.0
# Paris Eternal                                           18.0
# Philadelphia Fusion                                     12.0
# San Francisco Shock                                      1.0
# Seoul Dynasty                                            5.0
# Shanghai Dragons                                        10.0
# Toronto Defiant                                         17.0
# Vancouver Titans                                         2.0
# Washington Justice                                      16.0
#
#                         Average Control Points Earned  \
# Team Name
# Atlanta Reign                                  1.2904
# Boston Uprising                                0.8180
# Chengdu Hunters                                1.2500
# Dallas Fuel                                    1.1280
# Florida Mayhem                                 0.7534
# Guangzhou Charge                               1.3128
# Hangzhou Spark                                 1.3236
# Houston Outlaws                                1.1562
# London Spitfire                                1.2546
# Los Angeles Gladiators                         1.1678
# Los Angeles Valiant                            1.0916
# New York Excelsior                             1.3690
# Paris Eternal                                  0.9866
# Philadelphia Fusion                            1.0026
# San Francisco Shock                            1.5888
# Seoul Dynasty                                  1.3700
# Shanghai Dragons                               1.3450
# Toronto Defiant                                1.0394
# Vancouver Titans                               1.5170
# Washington Justice                             0.8500
#
#                         Average Control Points Lost  \
# Team Name
# Atlanta Reign                                1.0764
# Boston Uprising                              1.5638
# Chengdu Hunters                              1.2100
# Dallas Fuel                                  1.1584
# Florida Mayhem                               1.5706
# Guangzhou Charge                             1.0682
# Hangzhou Spark                               1.1042
# Houston Outlaws                              1.2646
# London Spitfire                              1.2016
# Los Angeles Gladiators                       1.1632
# Los Angeles Valiant                          1.2064
# New York Excelsior                           1.0052
# Paris Eternal                                1.4484
# Philadelphia Fusion                          1.4804
# San Francisco Shock                          0.8792
# Seoul Dynasty                                1.1900
# Shanghai Dragons                             1.1692
# Toronto Defiant                              1.3994
# Vancouver Titans                             0.8082
# Washington Justice                           1.6034
#
#                         Average Control Points Differential  ...  \
# Team Name                                                    ...
# Atlanta Reign                                        0.2140  ...
# Boston Uprising                                     -0.7458  ...
# Chengdu Hunters                                      0.0400  ...
# Dallas Fuel                                         -0.0304  ...
# Florida Mayhem                                      -0.8172  ...
# Guangzhou Charge                                     0.2446  ...
# Hangzhou Spark                                       0.2194  ...
# Houston Outlaws                                     -0.1084  ...
# London Spitfire                                      0.0530  ...
# Los Angeles Gladiators                               0.0046  ...
# Los Angeles Valiant                                 -0.1148  ...
# New York Excelsior                                   0.3638  ...
# Paris Eternal                                       -0.4618  ...
# Philadelphia Fusion                                 -0.4778  ...
# San Francisco Shock                                  0.7096  ...
# Seoul Dynasty                                        0.1800  ...
# Shanghai Dragons                                     0.1758  ...
# Toronto Defiant                                     -0.3600  ...
# Vancouver Titans                                     0.7088  ...
# Washington Justice                                  -0.7534  ...
#
#                         Average Hybrid True Win %  \
# Team Name
# Atlanta Reign                             57.3334
# Boston Uprising                           40.3334
# Chengdu Hunters                           49.6666
# Dallas Fuel                               32.8572
# Florida Mayhem                            31.7142
# Guangzhou Charge                          48.7858
# Hangzhou Spark                            45.9166
# Houston Outlaws                           34.1666
# London Spitfire                           50.2976
# Los Angeles Gladiators                    69.3334
# Los Angeles Valiant                       37.0476
# New York Excelsior                        63.1558
# Paris Eternal                             45.2500
# Philadelphia Fusion                       59.3334
# San Francisco Shock                       75.8938
# Seoul Dynasty                             60.2380
# Shanghai Dragons                          39.2500
# Toronto Defiant                           18.6030
# Vancouver Titans                          77.1428
# Washington Justice                        29.8572
#
#                         Average Hybrid Map Potential %  \
# Team Name
# Atlanta Reign                                   0.7708
# Boston Uprising                                 0.6908
# Chengdu Hunters                                 0.7758
# Dallas Fuel                                     0.6958
# Florida Mayhem                                  0.7178
# Guangzhou Charge                                0.7446
# Hangzhou Spark                                  0.7078
# Houston Outlaws                                 0.5592
# London Spitfire                                 0.7270
# Los Angeles Gladiators                          0.8632
# Los Angeles Valiant                             0.6836
# New York Excelsior                              0.8286
# Paris Eternal                                   0.7556
# Philadelphia Fusion                             0.7578
# San Francisco Shock                             0.9046
# Seoul Dynasty                                   0.8584
# Shanghai Dragons                                0.6854
# Toronto Defiant                                 0.6136
# Vancouver Titans                                0.8840
# Washington Justice                              0.6192
#
#                         Average Hybrid Map Potential % Rank  \
# Team Name
# Atlanta Reign                                           7.0
# Boston Uprising                                        15.0
# Chengdu Hunters                                         6.0
# Dallas Fuel                                            14.0
# Florida Mayhem                                         12.0
# Guangzhou Charge                                       10.0
# Hangzhou Spark                                         13.0
# Houston Outlaws                                        20.0
# London Spitfire                                        11.0
# Los Angeles Gladiators                                  3.0
# Los Angeles Valiant                                    17.0
# New York Excelsior                                      5.0
# Paris Eternal                                           9.0
# Philadelphia Fusion                                     8.0
# San Francisco Shock                                     1.0
# Seoul Dynasty                                           4.0
# Shanghai Dragons                                       16.0
# Toronto Defiant                                        19.0
# Vancouver Titans                                        2.0
# Washington Justice                                     18.0
#
#                         Average Escort Points Earned  \
# Team Name
# Atlanta Reign                               2.394500
# Boston Uprising                             1.894500
# Chengdu Hunters                             1.938833
# Dallas Fuel                                 2.241667
# Florida Mayhem                              1.863833
# Guangzhou Charge                            2.062667
# Hangzhou Spark                              2.261333
# Houston Outlaws                             1.841667
# London Spitfire                             2.038833
# Los Angeles Gladiators                      2.162500
# Los Angeles Valiant                         2.450000
# New York Excelsior                          2.105333
# Paris Eternal                               2.511167
# Philadelphia Fusion                         1.975167
# San Francisco Shock                         2.845833
# Seoul Dynasty                               2.270833
# Shanghai Dragons                            2.205500
# Toronto Defiant                             2.072167
# Vancouver Titans                            2.665500
# Washington Justice                          2.033333
#
#                         Average Escort Points Lost  \
# Team Name
# Atlanta Reign                             2.385667
# Boston Uprising                           2.222167
# Chengdu Hunters                           2.272167
# Dallas Fuel                               2.791667
# Florida Mayhem                            2.325000
# Guangzhou Charge                          2.338833
# Hangzhou Spark                            2.169500
# Houston Outlaws                           2.211167
# London Spitfire                           2.211167
# Los Angeles Gladiators                    2.062500
# Los Angeles Valiant                       2.108333
# New York Excelsior                        1.776167
# Paris Eternal                             2.361167
# Philadelphia Fusion                       1.972167
# San Francisco Shock                       1.380333
# Seoul Dynasty                             2.637333
# Shanghai Dragons                          2.232000
# Toronto Defiant                           2.702833
# Vancouver Titans                          2.186333
# Washington Justice                        2.550000
#
#                         Average Escort Points Differential  \
# Team Name
# Atlanta Reign                                     0.008833
# Boston Uprising                                  -0.327667
# Chengdu Hunters                                  -0.333333
# Dallas Fuel                                      -0.550000
# Florida Mayhem                                   -0.461167
# Guangzhou Charge                                 -0.276167
# Hangzhou Spark                                    0.091833
# Houston Outlaws                                  -0.369500
# London Spitfire                                  -0.172333
# Los Angeles Gladiators                            0.100000
# Los Angeles Valiant                               0.341667
# New York Excelsior                                0.329167
# Paris Eternal                                     0.150000
# Philadelphia Fusion                               0.003000
# San Francisco Shock                               1.465500
# Seoul Dynasty                                    -0.366500
# Shanghai Dragons                                 -0.026500
# Toronto Defiant                                  -0.630667
# Vancouver Titans                                  0.479167
# Washington Justice                               -0.516667
#
#                         Average Escort Points Differential Rank  \
# Team Name
# Atlanta Reign                                               8.0
# Boston Uprising                                            13.0
# Chengdu Hunters                                            14.0
# Dallas Fuel                                                19.0
# Florida Mayhem                                             17.0
# Guangzhou Charge                                           12.0
# Hangzhou Spark                                              7.0
# Houston Outlaws                                            16.0
# London Spitfire                                            11.0
# Los Angeles Gladiators                                      6.0
# Los Angeles Valiant                                         3.0
# New York Excelsior                                          4.0
# Paris Eternal                                               5.0
# Philadelphia Fusion                                         9.0
# San Francisco Shock                                         1.0
# Seoul Dynasty                                              15.0
# Shanghai Dragons                                           10.0
# Toronto Defiant                                            20.0
# Vancouver Titans                                            2.0
# Washington Justice                                         18.0
#
#                         Average Escort True Win %  \
# Team Name
# Atlanta Reign                           51.865000
# Boston Uprising                         33.333333
# Chengdu Hunters                         35.000000
# Dallas Fuel                             31.666667
# Florida Mayhem                          41.111167
# Guangzhou Charge                        43.531667
# Hangzhou Spark                          54.087500
# Houston Outlaws                         38.888833
# London Spitfire                         48.194500
# Los Angeles Gladiators                  49.166667
# Los Angeles Valiant                     62.777833
# New York Excelsior                      63.273833
# Paris Eternal                           56.944500
# Philadelphia Fusion                     55.833333
# San Francisco Shock                     90.773833
# Seoul Dynasty                           38.888833
# Shanghai Dragons                        44.027833
# Toronto Defiant                         30.277833
# Vancouver Titans                        68.042333
# Washington Justice                      33.333333
#
#                         Average Escort Map Potential %  \
# Team Name
# Atlanta Reign                                 0.799333
# Boston Uprising                               0.623500
# Chengdu Hunters                               0.663167
# Dallas Fuel                                   0.652167
# Florida Mayhem                                0.633333
# Guangzhou Charge                              0.686833
# Hangzhou Spark                                0.766667
# Houston Outlaws                               0.684167
# London Spitfire                               0.680333
# Los Angeles Gladiators                        0.728500
# Los Angeles Valiant                           0.773500
# New York Excelsior                            0.792333
# Paris Eternal                                 0.804833
# Philadelphia Fusion                           0.684333
# San Francisco Shock                           0.931500
# Seoul Dynasty                                 0.669000
# Shanghai Dragons                              0.720500
# Toronto Defiant                               0.642167
# Vancouver Titans                              0.846833
# Washington Justice                            0.651667
#
#                         Average Escort Map Potential % Rank
# Team Name
# Atlanta Reign                                           4.0
# Boston Uprising                                        20.0
# Chengdu Hunters                                        15.0
# Dallas Fuel                                            16.0
# Florida Mayhem                                         19.0
# Guangzhou Charge                                       10.0
# Hangzhou Spark                                          7.0
# Houston Outlaws                                        12.0
# London Spitfire                                        13.0
# Los Angeles Gladiators                                  8.0
# Los Angeles Valiant                                     6.0
# New York Excelsior                                      5.0
# Paris Eternal                                           3.0
# Philadelphia Fusion                                    11.0
# San Francisco Shock                                     1.0
# Seoul Dynasty                                          14.0
# Shanghai Dragons                                        9.0
# Toronto Defiant                                        18.0
# Vancouver Titans                                        2.0
# Washington Justice                                     17.0
#
# [20 rows x 28 columns]

# %%
#turning all important catagorical data into numeric data
def get_team_stats(team):
    teamrow = sta.loc[team, :]
    return teamrow

def home_team_winner(row):
    if row['home'] == row['winner']:
        return 1 
    else:
        return 0
    

finaldf = []
noplay = sdf[["stage", "away", "away id", "away score", "home score", "home id", "home", "winner", "winner id"]]

#combining stats and schedule dataframes
for index, row in noplay.iterrows():
    awayrow = get_team_stats(row["away"])
    homerow = get_team_stats(row["home"])
    awayrow = awayrow.rename(lambda x: "Away " + x)
    homerow = homerow.rename(lambda x: "Home " + x)
    test = pd.concat([row, awayrow, homerow], )
    finaldf.append(test)
finaldf = pd.DataFrame(finaldf)
finaldf.insert(finaldf.columns.get_loc("winner"), 'HomeTeamWin', finaldf.apply(home_team_winner, axis = 1))

#dropping all catagorical data
finaldf = finaldf.drop(["stage", "home", "away", 'away score', 'home score', "winner", "winner id"], axis = 1)
finaldf = finaldf.loc[:, ~finaldf.columns.str.contains("Rank")]


finaldf
# Out:
#      away id  home id  HomeTeamWin  Away Average Assault Points Earned  \
# 0       4524     4410            0                              2.3196
# 1       4403     4402            0                              2.1624
# 2       4409     4406            0                              2.3574
# 3       4408     7693            1                              2.6066
# 4       7695     4525            0                              1.9016
# 5       7698     4407            0                              2.3416
# 6       4523     4404            1                              2.2092
# 7       7692     7699            0                              2.2584
# 8       4410     7694            1                              2.2620
# 9       7697     4403            1                              1.5908
# 10      4405     7693            1                              2.1220
# 11      7696     4408            0                              2.1022
# 12      4525     4402            1                              1.7492
# 13      4524     7698            0                              2.3196
# 14      4404     4406            1                              2.7654
# 15      4409     4523            1                              2.3574
# 16      7697     4410            1                              1.5908
# 17      4524     4407            1                              2.3196
# 18      7699     4523            0                              2.2058
# 19      4409     7692            0                              2.3574
# 20      7698     7695            0                              2.3416
# 21      4403     4405            0                              2.1624
# 22      4408     4402            0                              2.6066
# 23      4525     7693            0                              1.7492
# 24      4406     7694            1                              2.1894
# 25      4524     4523            1                              2.3196
# 26      7696     7699            0                              2.1022
# 27      7692     4407            0                              2.2584
# 28      7693     4410            1                              2.1294
# 29      4403     4525            0                              2.1624
# ..       ...      ...          ...                                 ...
# 289     4410     7698            1                              2.2620
# 290     7694     7697            1                              1.9966
# 291     4407     7695            0                              2.4058
# 292     4523     7699            1                              2.2092
# 293     7698     4523            0                              2.3416
# 294     4402     4403            1                              2.3466
# 295     4404     7696            0                              2.7654
# 296     4406     4405            0                              2.1894
# 297     7693     4408            0                              2.1294
# 298     7698     4402            0                              2.3416
# 299     4403     7696            1                              2.1624
# 300     4404     4405            0                              2.7654
# 301     7692     7699            1                              2.2584
# 302     4408     4524            0                              2.6066
# 303     4408     4410            1                              2.6066
# 304     7699     4409            1                              2.2058
# 305     4409     7696            1                              2.3574
# 306     4406     7693            0                              2.1894
# 307     4410     4403            1                              2.2620
# 308     7698     4404            0                              2.3416
# 309     4409     7693            1                              2.3574
# 310     4410     4404            1                              2.2620
# 311     4406     7696            1                              2.1894
# 312     7698     4403            1                              2.3416
# 313     7698     7693            1                              2.3416
# 314     4406     4404            1                              2.1894
# 315     4403     7696            1                              2.1624
# 316     7693     4404            1                              2.1294
# 317     4404     4403            0                              2.7654
# 318     4404     7696            0                              2.7654
#
#      Away Average Assault Points Lost  \
# 0                              2.6138
# 1                              1.9222
# 2                              2.2094
# 3                              2.5466
# 4                              2.2484
# 5                              2.1500
# 6                              2.7736
# 7                              2.3084
# 8                              2.0416
# 9                              1.9764
# 10                             2.1752
# 11                             1.8444
# 12                             2.0878
# 13                             2.6138
# 14                             1.8650
# 15                             2.2094
# 16                             1.9764
# 17                             2.6138
# 18                             2.1962
# 19                             2.2094
# 20                             2.1500
# 21                             1.9222
# 22                             2.5466
# 23                             2.0878
# 24                             1.9448
# 25                             2.6138
# 26                             1.8444
# 27                             2.3084
# 28                             2.0376
# 29                             1.9222
# ..                                ...
# 289                            2.0416
# 290                            2.3534
# 291                            2.6104
# 292                            2.7736
# 293                            2.1500
# 294                            2.6266
# 295                            1.8650
# 296                            1.9448
# 297                            2.0376
# 298                            2.1500
# 299                            1.9222
# 300                            1.8650
# 301                            2.3084
# 302                            2.5466
# 303                            2.5466
# 304                            2.1962
# 305                            2.2094
# 306                            1.9448
# 307                            2.0416
# 308                            2.1500
# 309                            2.2094
# 310                            2.0416
# 311                            1.9448
# 312                            2.1500
# 313                            2.1500
# 314                            1.9448
# 315                            1.9222
# 316                            2.0376
# 317                            1.8650
# 318                            1.8650
#
#      Away Average Assault Points Differential  \
# 0                                     -0.2942
# 1                                      0.2402
# 2                                      0.1480
# 3                                      0.0600
# 4                                     -0.3468
# 5                                      0.1916
# 6                                     -0.5644
# 7                                     -0.0500
# 8                                      0.2204
# 9                                     -0.3856
# 10                                    -0.0532
# 11                                     0.2578
# 12                                    -0.3386
# 13                                    -0.2942
# 14                                     0.9004
# 15                                     0.1480
# 16                                    -0.3856
# 17                                    -0.2942
# 18                                     0.0096
# 19                                     0.1480
# 20                                     0.1916
# 21                                     0.2402
# 22                                     0.0600
# 23                                    -0.3386
# 24                                     0.2446
# 25                                    -0.2942
# 26                                     0.2578
# 27                                    -0.0500
# 28                                     0.0918
# 29                                     0.2402
# ..                                        ...
# 289                                    0.2204
# 290                                   -0.3568
# 291                                   -0.2046
# 292                                   -0.5644
# 293                                    0.1916
# 294                                   -0.2800
# 295                                    0.9004
# 296                                    0.2446
# 297                                    0.0918
# 298                                    0.1916
# 299                                    0.2402
# 300                                    0.9004
# 301                                   -0.0500
# 302                                    0.0600
# 303                                    0.0600
# 304                                    0.0096
# 305                                    0.1480
# 306                                    0.2446
# 307                                    0.2204
# 308                                    0.1916
# 309                                    0.1480
# 310                                    0.2204
# 311                                    0.2446
# 312                                    0.1916
# 313                                    0.1916
# 314                                    0.2446
# 315                                    0.2402
# 316                                    0.0918
# 317                                    0.9004
# 318                                    0.9004
#
#      Away Average Assault True Win %  Away Average Assault Map Potential %  \
# 0                            36.9446                                0.7500
# 1                            59.9884                                0.8234
# 2                            53.3056                                0.7998
# 3                            55.0000                                0.7742
# 4                            38.8334                                0.6884
# 5                            55.0000                                0.7510
# 6                            28.2858                                0.6474
# 7                            45.8334                                0.7890
# 8                            57.6786                                0.7848
# 9                            41.0714                                0.6902
# 10                           46.0834                                0.7910
# 11                           64.6668                                0.8288
# 12                           36.0000                                0.5490
# 13                           36.9446                                0.7500
# 14                           87.6882                                0.9292
# 15                           53.3056                                0.7998
# 16                           41.0714                                0.6902
# 17                           36.9446                                0.7500
# 18                           50.6192                                0.7120
# 19                           53.3056                                0.7998
# 20                           55.0000                                0.7510
# 21                           59.9884                                0.8234
# 22                           55.0000                                0.7742
# 23                           36.0000                                0.5490
# 24                           57.1516                                0.8010
# 25                           36.9446                                0.7500
# 26                           64.6668                                0.8288
# 27                           45.8334                                0.7890
# 28                           56.8572                                0.7934
# 29                           59.9884                                0.8234
# ..                               ...                                   ...
# 289                          57.6786                                0.7848
# 290                          36.7500                                0.6822
# 291                          38.3332                                0.7464
# 292                          28.2858                                0.6474
# 293                          55.0000                                0.7510
# 294                          33.5000                                0.7144
# 295                          87.6882                                0.9292
# 296                          57.1516                                0.8010
# 297                          56.8572                                0.7934
# 298                          55.0000                                0.7510
# 299                          59.9884                                0.8234
# 300                          87.6882                                0.9292
# 301                          45.8334                                0.7890
# 302                          55.0000                                0.7742
# 303                          55.0000                                0.7742
# 304                          50.6192                                0.7120
# 305                          53.3056                                0.7998
# 306                          57.1516                                0.8010
# 307                          57.6786                                0.7848
# 308                          55.0000                                0.7510
# 309                          53.3056                                0.7998
# 310                          57.6786                                0.7848
# 311                          57.1516                                0.8010
# 312                          55.0000                                0.7510
# 313                          55.0000                                0.7510
# 314                          57.1516                                0.8010
# 315                          59.9884                                0.8234
# 316                          56.8572                                0.7934
# 317                          87.6882                                0.9292
# 318                          87.6882                                0.9292
#
#      Away Average Control Points Earned  Away Average Control Points Lost  \
# 0                                1.0026                            1.4804
# 1                                1.3690                            1.0052
# 2                                1.3700                            1.1900
# 3                                1.3450                            1.1692
# 4                                1.0394                            1.3994
# 5                                1.2904                            1.0764
# 6                                1.1280                            1.1584
# 7                                1.2500                            1.2100
# 8                                1.2546                            1.2016
# 9                                0.8500                            1.6034
# 10                               1.0916                            1.2064
# 11                               1.5170                            0.8082
# 12                               1.1562                            1.2646
# 13                               1.0026                            1.4804
# 14                               1.5888                            0.8792
# 15                               1.3700                            1.1900
# 16                               0.8500                            1.6034
# 17                               1.0026                            1.4804
# 18                               1.3128                            1.0682
# 19                               1.3700                            1.1900
# 20                               1.2904                            1.0764
# 21                               1.3690                            1.0052
# 22                               1.3450                            1.1692
# 23                               1.1562                            1.2646
# 24                               1.1678                            1.1632
# 25                               1.0026                            1.4804
# 26                               1.5170                            0.8082
# 27                               1.2500                            1.2100
# 28                               1.3236                            1.1042
# 29                               1.3690                            1.0052
# ..                                  ...                               ...
# 289                              1.2546                            1.2016
# 290                              0.9866                            1.4484
# 291                              0.7534                            1.5706
# 292                              1.1280                            1.1584
# 293                              1.2904                            1.0764
# 294                              0.8180                            1.5638
# 295                              1.5888                            0.8792
# 296                              1.1678                            1.1632
# 297                              1.3236                            1.1042
# 298                              1.2904                            1.0764
# 299                              1.3690                            1.0052
# 300                              1.5888                            0.8792
# 301                              1.2500                            1.2100
# 302                              1.3450                            1.1692
# 303                              1.3450                            1.1692
# 304                              1.3128                            1.0682
# 305                              1.3700                            1.1900
# 306                              1.1678                            1.1632
# 307                              1.2546                            1.2016
# 308                              1.2904                            1.0764
# 309                              1.3700                            1.1900
# 310                              1.2546                            1.2016
# 311                              1.1678                            1.1632
# 312                              1.2904                            1.0764
# 313                              1.2904                            1.0764
# 314                              1.1678                            1.1632
# 315                              1.3690                            1.0052
# 316                              1.3236                            1.1042
# 317                              1.5888                            0.8792
# 318                              1.5888                            0.8792
#
#      ...  Home Average Hybrid Points Earned  Home Average Hybrid Points Lost  \
# 0    ...                             2.2656                           2.5166
# 1    ...                             2.2316                           2.4650
# 2    ...                             2.4400                           2.0434
# 3    ...                             2.4034                           2.3216
# 4    ...                             1.6952                           2.3442
# 5    ...                             2.0524                           2.5780
# 6    ...                             2.8054                           1.8916
# 7    ...                             2.3514                           2.3986
# 8    ...                             2.5834                           2.7400
# 9    ...                             2.5336                           2.0938
# 10   ...                             2.4034                           2.3216
# 11   ...                             2.0800                           2.1550
# 12   ...                             2.2316                           2.4650
# 13   ...                             2.3334                           2.1668
# 14   ...                             2.4400                           2.0434
# 15   ...                             2.1428                           2.5728
# 16   ...                             2.2656                           2.5166
# 17   ...                             2.0524                           2.5780
# 18   ...                             2.1428                           2.5728
# 19   ...                             2.4500                           2.2968
# 20   ...                             1.8380                           2.7592
# 21   ...                             2.1608                           2.3914
# 22   ...                             2.2316                           2.4650
# 23   ...                             2.4034                           2.3216
# 24   ...                             2.5834                           2.7400
# 25   ...                             2.1428                           2.5728
# 26   ...                             2.3514                           2.3986
# 27   ...                             2.0524                           2.5780
# 28   ...                             2.2656                           2.5166
# 29   ...                             1.6952                           2.3442
# ..   ...                                ...                              ...
# 289  ...                             2.3334                           2.1668
# 290  ...                             1.7028                           2.3116
# 291  ...                             1.8380                           2.7592
# 292  ...                             2.3514                           2.3986
# 293  ...                             2.1428                           2.5728
# 294  ...                             2.5336                           2.0938
# 295  ...                             2.6254                           2.0042
# 296  ...                             2.1608                           2.3914
# 297  ...                             2.0800                           2.1550
# 298  ...                             2.2316                           2.4650
# 299  ...                             2.6254                           2.0042
# 300  ...                             2.1608                           2.3914
# 301  ...                             2.3514                           2.3986
# 302  ...                             2.0984                           2.0450
# 303  ...                             2.2656                           2.5166
# 304  ...                             2.6260                           2.3012
# 305  ...                             2.6254                           2.0042
# 306  ...                             2.4034                           2.3216
# 307  ...                             2.5336                           2.0938
# 308  ...                             2.8054                           1.8916
# 309  ...                             2.4034                           2.3216
# 310  ...                             2.8054                           1.8916
# 311  ...                             2.6254                           2.0042
# 312  ...                             2.5336                           2.0938
# 313  ...                             2.4034                           2.3216
# 314  ...                             2.8054                           1.8916
# 315  ...                             2.6254                           2.0042
# 316  ...                             2.8054                           1.8916
# 317  ...                             2.5336                           2.0938
# 318  ...                             2.6254                           2.0042
#
#      Home Average Hybrid Points Differential  Home Average Hybrid True Win %  \
# 0                                    -0.2510                         50.2976
# 1                                    -0.2334                         40.3334
# 2                                     0.3966                         69.3334
# 3                                     0.0818                         45.9166
# 4                                    -0.6490                         34.1666
# 5                                    -0.5256                         31.7142
# 6                                     0.9138                         75.8938
# 7                                    -0.0472                         48.7858
# 8                                    -0.1566                         45.2500
# 9                                     0.4398                         63.1558
# 10                                    0.0818                         45.9166
# 11                                   -0.0750                         39.2500
# 12                                   -0.2334                         40.3334
# 13                                    0.1666                         57.3334
# 14                                    0.3966                         69.3334
# 15                                   -0.4300                         32.8572
# 16                                   -0.2510                         50.2976
# 17                                   -0.5256                         31.7142
# 18                                   -0.4300                         32.8572
# 19                                    0.1532                         49.6666
# 20                                   -0.9212                         18.6030
# 21                                   -0.2306                         37.0476
# 22                                   -0.2334                         40.3334
# 23                                    0.0818                         45.9166
# 24                                   -0.1566                         45.2500
# 25                                   -0.4300                         32.8572
# 26                                   -0.0472                         48.7858
# 27                                   -0.5256                         31.7142
# 28                                   -0.2510                         50.2976
# 29                                   -0.6490                         34.1666
# ..                                       ...                             ...
# 289                                   0.1666                         57.3334
# 290                                  -0.6088                         29.8572
# 291                                  -0.9212                         18.6030
# 292                                  -0.0472                         48.7858
# 293                                  -0.4300                         32.8572
# 294                                   0.4398                         63.1558
# 295                                   0.6212                         77.1428
# 296                                  -0.2306                         37.0476
# 297                                  -0.0750                         39.2500
# 298                                  -0.2334                         40.3334
# 299                                   0.6212                         77.1428
# 300                                  -0.2306                         37.0476
# 301                                  -0.0472                         48.7858
# 302                                   0.0534                         59.3334
# 303                                  -0.2510                         50.2976
# 304                                   0.3248                         60.2380
# 305                                   0.6212                         77.1428
# 306                                   0.0818                         45.9166
# 307                                   0.4398                         63.1558
# 308                                   0.9138                         75.8938
# 309                                   0.0818                         45.9166
# 310                                   0.9138                         75.8938
# 311                                   0.6212                         77.1428
# 312                                   0.4398                         63.1558
# 313                                   0.0818                         45.9166
# 314                                   0.9138                         75.8938
# 315                                   0.6212                         77.1428
# 316                                   0.9138                         75.8938
# 317                                   0.4398                         63.1558
# 318                                   0.6212                         77.1428
#
#      Home Average Hybrid Map Potential %  Home Average Escort Points Earned  \
# 0                                 0.7270                           2.038833
# 1                                 0.6908                           1.894500
# 2                                 0.8632                           2.162500
# 3                                 0.7078                           2.261333
# 4                                 0.5592                           1.841667
# 5                                 0.7178                           1.863833
# 6                                 0.9046                           2.845833
# 7                                 0.7446                           2.062667
# 8                                 0.7556                           2.511167
# 9                                 0.8286                           2.105333
# 10                                0.7078                           2.261333
# 11                                0.6854                           2.205500
# 12                                0.6908                           1.894500
# 13                                0.7708                           2.394500
# 14                                0.8632                           2.162500
# 15                                0.6958                           2.241667
# 16                                0.7270                           2.038833
# 17                                0.7178                           1.863833
# 18                                0.6958                           2.241667
# 19                                0.7758                           1.938833
# 20                                0.6136                           2.072167
# 21                                0.6836                           2.450000
# 22                                0.6908                           1.894500
# 23                                0.7078                           2.261333
# 24                                0.7556                           2.511167
# 25                                0.6958                           2.241667
# 26                                0.7446                           2.062667
# 27                                0.7178                           1.863833
# 28                                0.7270                           2.038833
# 29                                0.5592                           1.841667
# ..                                   ...                                ...
# 289                               0.7708                           2.394500
# 290                               0.6192                           2.033333
# 291                               0.6136                           2.072167
# 292                               0.7446                           2.062667
# 293                               0.6958                           2.241667
# 294                               0.8286                           2.105333
# 295                               0.8840                           2.665500
# 296                               0.6836                           2.450000
# 297                               0.6854                           2.205500
# 298                               0.6908                           1.894500
# 299                               0.8840                           2.665500
# 300                               0.6836                           2.450000
# 301                               0.7446                           2.062667
# 302                               0.7578                           1.975167
# 303                               0.7270                           2.038833
# 304                               0.8584                           2.270833
# 305                               0.8840                           2.665500
# 306                               0.7078                           2.261333
# 307                               0.8286                           2.105333
# 308                               0.9046                           2.845833
# 309                               0.7078                           2.261333
# 310                               0.9046                           2.845833
# 311                               0.8840                           2.665500
# 312                               0.8286                           2.105333
# 313                               0.7078                           2.261333
# 314                               0.9046                           2.845833
# 315                               0.8840                           2.665500
# 316                               0.9046                           2.845833
# 317                               0.8286                           2.105333
# 318                               0.8840                           2.665500
#
#      Home Average Escort Points Lost  Home Average Escort Points Differential  \
# 0                           2.211167                                -0.172333
# 1                           2.222167                                -0.327667
# 2                           2.062500                                 0.100000
# 3                           2.169500                                 0.091833
# 4                           2.211167                                -0.369500
# 5                           2.325000                                -0.461167
# 6                           1.380333                                 1.465500
# 7                           2.338833                                -0.276167
# 8                           2.361167                                 0.150000
# 9                           1.776167                                 0.329167
# 10                          2.169500                                 0.091833
# 11                          2.232000                                -0.026500
# 12                          2.222167                                -0.327667
# 13                          2.385667                                 0.008833
# 14                          2.062500                                 0.100000
# 15                          2.791667                                -0.550000
# 16                          2.211167                                -0.172333
# 17                          2.325000                                -0.461167
# 18                          2.791667                                -0.550000
# 19                          2.272167                                -0.333333
# 20                          2.702833                                -0.630667
# 21                          2.108333                                 0.341667
# 22                          2.222167                                -0.327667
# 23                          2.169500                                 0.091833
# 24                          2.361167                                 0.150000
# 25                          2.791667                                -0.550000
# 26                          2.338833                                -0.276167
# 27                          2.325000                                -0.461167
# 28                          2.211167                                -0.172333
# 29                          2.211167                                -0.369500
# ..                               ...                                      ...
# 289                         2.385667                                 0.008833
# 290                         2.550000                                -0.516667
# 291                         2.702833                                -0.630667
# 292                         2.338833                                -0.276167
# 293                         2.791667                                -0.550000
# 294                         1.776167                                 0.329167
# 295                         2.186333                                 0.479167
# 296                         2.108333                                 0.341667
# 297                         2.232000                                -0.026500
# 298                         2.222167                                -0.327667
# 299                         2.186333                                 0.479167
# 300                         2.108333                                 0.341667
# 301                         2.338833                                -0.276167
# 302                         1.972167                                 0.003000
# 303                         2.211167                                -0.172333
# 304                         2.637333                                -0.366500
# 305                         2.186333                                 0.479167
# 306                         2.169500                                 0.091833
# 307                         1.776167                                 0.329167
# 308                         1.380333                                 1.465500
# 309                         2.169500                                 0.091833
# 310                         1.380333                                 1.465500
# 311                         2.186333                                 0.479167
# 312                         1.776167                                 0.329167
# 313                         2.169500                                 0.091833
# 314                         1.380333                                 1.465500
# 315                         2.186333                                 0.479167
# 316                         1.380333                                 1.465500
# 317                         1.776167                                 0.329167
# 318                         2.186333                                 0.479167
#
#      Home Average Escort True Win %  Home Average Escort Map Potential %
# 0                         48.194500                             0.680333
# 1                         33.333333                             0.623500
# 2                         49.166667                             0.728500
# 3                         54.087500                             0.766667
# 4                         38.888833                             0.684167
# 5                         41.111167                             0.633333
# 6                         90.773833                             0.931500
# 7                         43.531667                             0.686833
# 8                         56.944500                             0.804833
# 9                         63.273833                             0.792333
# 10                        54.087500                             0.766667
# 11                        44.027833                             0.720500
# 12                        33.333333                             0.623500
# 13                        51.865000                             0.799333
# 14                        49.166667                             0.728500
# 15                        31.666667                             0.652167
# 16                        48.194500                             0.680333
# 17                        41.111167                             0.633333
# 18                        31.666667                             0.652167
# 19                        35.000000                             0.663167
# 20                        30.277833                             0.642167
# 21                        62.777833                             0.773500
# 22                        33.333333                             0.623500
# 23                        54.087500                             0.766667
# 24                        56.944500                             0.804833
# 25                        31.666667                             0.652167
# 26                        43.531667                             0.686833
# 27                        41.111167                             0.633333
# 28                        48.194500                             0.680333
# 29                        38.888833                             0.684167
# ..                              ...                                  ...
# 289                       51.865000                             0.799333
# 290                       33.333333                             0.651667
# 291                       30.277833                             0.642167
# 292                       43.531667                             0.686833
# 293                       31.666667                             0.652167
# 294                       63.273833                             0.792333
# 295                       68.042333                             0.846833
# 296                       62.777833                             0.773500
# 297                       44.027833                             0.720500
# 298                       33.333333                             0.623500
# 299                       68.042333                             0.846833
# 300                       62.777833                             0.773500
# 301                       43.531667                             0.686833
# 302                       55.833333                             0.684333
# 303                       48.194500                             0.680333
# 304                       38.888833                             0.669000
# 305                       68.042333                             0.846833
# 306                       54.087500                             0.766667
# 307                       63.273833                             0.792333
# 308                       90.773833                             0.931500
# 309                       54.087500                             0.766667
# 310                       90.773833                             0.931500
# 311                       68.042333                             0.846833
# 312                       63.273833                             0.792333
# 313                       54.087500                             0.766667
# 314                       90.773833                             0.931500
# 315                       68.042333                             0.846833
# 316                       90.773833                             0.931500
# 317                       63.273833                             0.792333
# 318                       68.042333                             0.846833
#
# [319 rows x 43 columns]

# %%
#setting all data to same scale
from sklearn.preprocessing import scale

X = finaldf.loc[:, ~finaldf.columns.isin(['HomeTeamWin'])]
y = finaldf.loc[:, 'HomeTeamWin']

for col in X.loc[:, "Away Average Assault Points Earned": "Home Average Escort Map Potential %"].columns:
    X[col] = scale(X[col])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#      away id  home id  Away Average Assault Points Earned  \
# 0       4524     4410                            0.383535
# 1       4403     4402                           -0.218600
# 2       4409     4406                            0.528323
# 3       4408     7693                            1.482853
# 4       7695     4525                           -1.217563
# 5       7698     4407                            0.467803
# 6       4523     4404                           -0.039339
# 7       7692     7699                            0.149116
# 8       4410     7694                            0.162905
# 9       7697     4403                           -2.408044
# 10      4405     7693                           -0.373348
# 11      7696     4408                           -0.449189
# 12      4525     4402                           -1.801312
# 13      4524     7698                            0.383535
# 14      4404     4406                            2.091117
# 15      4409     4523                            0.528323
# 16      7697     4410                           -2.408044
# 17      4524     4407                            0.383535
# 18      7699     4523                           -0.052362
# 19      4409     7692                            0.528323
# 20      7698     7695                            0.467803
# 21      4403     4405                           -0.218600
# 22      4408     4402                            1.482853
# 23      4525     7693                           -1.801312
# 24      4406     7694                           -0.115180
# 25      4524     4523                            0.383535
# 26      7696     7699                           -0.449189
# 27      7692     4407                            0.149116
# 28      7693     4410                           -0.345003
# 29      4403     4525                           -0.218600
# ..       ...      ...                                 ...
# 289     4410     7698                            0.162905
# 290     7694     7697                           -0.853677
# 291     4407     7695                            0.713713
# 292     4523     7699                           -0.039339
# 293     7698     4523                            0.467803
# 294     4402     4403                            0.486955
# 295     4404     7696                            2.091117
# 296     4406     4405                           -0.115180
# 297     7693     4408                           -0.345003
# 298     7698     4402                            0.467803
# 299     4403     7696                           -0.218600
# 300     4404     4405                            2.091117
# 301     7692     7699                            0.149116
# 302     4408     4524                            1.482853
# 303     4408     4410                            1.482853
# 304     7699     4409                           -0.052362
# 305     4409     7696                            0.528323
# 306     4406     7693                           -0.115180
# 307     4410     4403                            0.162905
# 308     7698     4404                            0.467803
# 309     4409     7693                            0.528323
# 310     4410     4404                            0.162905
# 311     4406     7696                           -0.115180
# 312     7698     4403                            0.467803
# 313     7698     7693                            0.467803
# 314     4406     4404                           -0.115180
# 315     4403     7696                           -0.218600
# 316     7693     4404                           -0.345003
# 317     4404     4403                            2.091117
# 318     4404     7696                            2.091117
#
#      Away Average Assault Points Lost  \
# 0                            1.456770
# 1                           -1.091522
# 2                           -0.033296
# 3                            1.209162
# 4                            0.110405
# 5                           -0.252163
# 6                            2.045574
# 7                            0.331483
# 8                           -0.651577
# 9                           -0.891815
# 10                          -0.159310
# 11                          -1.378186
# 12                          -0.481347
# 13                           1.456770
# 14                          -1.302283
# 15                          -0.033296
# 16                          -0.891815
# 17                           1.456770
# 18                          -0.081933
# 19                          -0.033296
# 20                          -0.252163
# 21                          -1.091522
# 22                           1.209162
# 23                          -0.481347
# 24                          -1.008249
# 25                           1.456770
# 26                          -1.378186
# 27                           0.331483
# 28                          -0.666315
# 29                          -1.091522
# ..                                ...
# 289                         -0.651577
# 290                          0.497291
# 291                          1.444242
# 292                          2.045574
# 293                         -0.252163
# 294                          1.503933
# 295                         -1.302283
# 296                         -1.008249
# 297                         -0.666315
# 298                         -0.252163
# 299                         -1.091522
# 300                         -1.302283
# 301                          0.331483
# 302                          1.209162
# 303                          1.209162
# 304                         -0.081933
# 305                         -0.033296
# 306                         -1.008249
# 307                         -0.651577
# 308                         -0.252163
# 309                         -0.033296
# 310                         -0.651577
# 311                         -1.008249
# 312                         -0.252163
# 313                         -0.252163
# 314                         -1.008249
# 315                         -1.091522
# 316                         -0.666315
# 317                         -1.302283
# 318                         -1.302283
#
#      Away Average Assault Points Differential  \
# 0                                   -0.884121
# 1                                    0.716218
# 2                                    0.440112
# 3                                    0.176583
# 4                                   -1.041640
# 5                                    0.570678
# 6                                   -1.693275
# 7                                   -0.152828
# 8                                    0.656924
# 9                                   -1.157832
# 10                                  -0.162411
# 11                                   0.768924
# 12                                  -1.017084
# 13                                  -0.884121
# 14                                   2.693285
# 15                                   0.440112
# 16                                  -1.157832
# 17                                  -0.884121
# 18                                   0.025653
# 19                                   0.440112
# 20                                   0.570678
# 21                                   0.716218
# 22                                   0.176583
# 23                                  -1.017084
# 24                                   0.729395
# 25                                  -0.884121
# 26                                   0.768924
# 27                                  -0.152828
# 28                                   0.271813
# 29                                   0.716218
# ..                                        ...
# 289                                  0.656924
# 290                                 -1.071586
# 291                                 -0.615801
# 292                                 -1.693275
# 293                                  0.570678
# 294                                 -0.841597
# 295                                  2.693285
# 296                                  0.729395
# 297                                  0.271813
# 298                                  0.570678
# 299                                  0.716218
# 300                                  2.693285
# 301                                 -0.152828
# 302                                  0.176583
# 303                                  0.176583
# 304                                  0.025653
# 305                                  0.440112
# 306                                  0.729395
# 307                                  0.656924
# 308                                  0.570678
# 309                                  0.440112
# 310                                  0.656924
# 311                                  0.729395
# 312                                  0.570678
# 313                                  0.570678
# 314                                  0.729395
# 315                                  0.716218
# 316                                  0.271813
# 317                                  2.693285
# 318                                  2.693285
#
#      Away Average Assault True Win %  Away Average Assault Map Potential %  \
# 0                          -0.954492                             -0.093244
# 1                           0.727167                              0.844508
# 2                           0.239479                              0.542997
# 3                           0.363131                              0.215933
# 4                          -0.816654                             -0.880241
# 5                           0.363131                             -0.080468
# 6                          -1.586382                             -1.404054
# 7                          -0.305817                              0.405017
# 8                           0.558606                              0.351358
# 9                          -0.653332                             -0.857244
# 10                         -0.287573                              0.430569
# 11                          1.068582                              0.913498
# 12                         -1.023426                             -2.661205
# 13                         -0.954492                             -0.093244
# 14                          2.748606                              2.196201
# 15                          0.239479                              0.542997
# 16                         -0.653332                             -0.857244
# 17                         -0.954492                             -0.093244
# 18                          0.043435                             -0.578729
# 19                          0.239479                              0.542997
# 20                          0.363131                             -0.080468
# 21                          0.727167                              0.844508
# 22                          0.363131                              0.215933
# 23                         -1.023426                             -2.661205
# 24                          0.520147                              0.558328
# 25                         -0.954492                             -0.093244
# 26                          1.068582                              0.913498
# 27                         -0.305817                              0.405017
# 28                          0.498663                              0.461231
# 29                          0.727167                              0.844508
# ..                               ...                                   ...
# 289                         0.558606                              0.351358
# 290                        -0.968693                             -0.959452
# 291                        -0.853157                             -0.139238
# 292                        -1.586382                             -1.404054
# 293                         0.363131                             -0.080468
# 294                        -1.205867                             -0.548067
# 295                         2.748606                              2.196201
# 296                         0.520147                              0.558328
# 297                         0.498663                              0.461231
# 298                         0.363131                             -0.080468
# 299                         0.727167                              0.844508
# 300                         2.748606                              2.196201
# 301                        -0.305817                              0.405017
# 302                         0.363131                              0.215933
# 303                         0.363131                              0.215933
# 304                         0.043435                             -0.578729
# 305                         0.239479                              0.542997
# 306                         0.520147                              0.558328
# 307                         0.558606                              0.351358
# 308                         0.363131                             -0.080468
# 309                         0.239479                              0.542997
# 310                         0.558606                              0.351358
# 311                         0.520147                              0.558328
# 312                         0.363131                             -0.080468
# 313                         0.363131                             -0.080468
# 314                         0.520147                              0.558328
# 315                         0.727167                              0.844508
# 316                         0.498663                              0.461231
# 317                         2.748606                              2.196201
# 318                         2.748606                              2.196201
#
#      Away Average Control Points Earned  Away Average Control Points Lost  \
# 0                             -0.897993                          1.253639
# 1                              0.787849                         -0.985190
# 2                              0.792450                         -0.114534
# 3                              0.677423                         -0.212530
# 4                             -0.728672                          0.872021
# 5                              0.426203                         -0.649743
# 6                             -0.321015                         -0.263413
# 7                              0.240319                         -0.020308
# 8                              0.261484                         -0.059883
# 9                             -1.600120                          1.833134
# 10                            -0.488495                         -0.037268
# 11                             1.468812                         -1.913324
# 12                            -0.191264                          0.236932
# 13                            -0.897993                          1.253639
# 14                             1.799170                         -1.578819
# 15                             0.792450                         -0.114534
# 16                            -1.600120                          1.833134
# 17                            -0.897993                          1.253639
# 18                             0.529268                         -0.688376
# 19                             0.792450                         -0.114534
# 20                             0.426203                         -0.649743
# 21                             0.787849                         -0.985190
# 22                             0.677423                         -0.212530
# 23                            -0.191264                          0.236932
# 24                            -0.137892                         -0.240798
# 25                            -0.897993                          1.253639
# 26                             1.468812                         -1.913324
# 27                             0.240319                         -0.020308
# 28                             0.578959                         -0.518767
# 29                             0.787849                         -0.985190
# ..                                  ...                               ...
# 289                            0.261484                         -0.059883
# 290                           -0.971610                          1.102876
# 291                           -2.044586                          1.678602
# 292                           -0.321015                         -0.263413
# 293                            0.426203                         -0.649743
# 294                           -1.747355                          1.646565
# 295                            1.799170                         -1.578819
# 296                           -0.137892                         -0.240798
# 297                            0.578959                         -0.518767
# 298                            0.426203                         -0.649743
# 299                            0.787849                         -0.985190
# 300                            1.799170                         -1.578819
# 301                            0.240319                         -0.020308
# 302                            0.677423                         -0.212530
# 303                            0.677423                         -0.212530
# 304                            0.529268                         -0.688376
# 305                            0.792450                         -0.114534
# 306                           -0.137892                         -0.240798
# 307                            0.261484                         -0.059883
# 308                            0.426203                         -0.649743
# 309                            0.792450                         -0.114534
# 310                            0.261484                         -0.059883
# 311                           -0.137892                         -0.240798
# 312                            0.426203                         -0.649743
# 313                            0.426203                         -0.649743
# 314                           -0.137892                         -0.240798
# 315                            0.787849                         -0.985190
# 316                            0.578959                         -0.518767
# 317                            1.799170                         -1.578819
# 318                            1.799170                         -1.578819
#
#      Away Average Control Points Differential  ...  \
# 0                                   -1.089809  ...
# 1                                    0.898625  ...
# 2                                    0.464364  ...
# 3                                    0.454441  ...
# 4                                   -0.811485  ...
# 5                                    0.544695  ...
# 6                                   -0.032744  ...
# 7                                    0.133589  ...
# 8                                    0.164303  ...
# 9                                   -1.740964  ...
# 10                                  -0.232155  ...
# 11                                   1.713751  ...
# 12                                  -0.217034  ...
# 13                                  -1.089809  ...
# 14                                   1.715641  ...
# 15                                   0.464364  ...
# 16                                  -1.740964  ...
# 17                                  -1.089809  ...
# 18                                   0.616993  ...
# 19                                   0.464364  ...
# 20                                   0.544695  ...
# 21                                   0.898625  ...
# 22                                   0.454441  ...
# 23                                  -0.217034  ...
# 24                                   0.049950  ...
# 25                                  -1.089809  ...
# 26                                   1.713751  ...
# 27                                   0.133589  ...
# 28                                   0.557454  ...
# 29                                   0.898625  ...
# ..                                        ...  ...
# 289                                  0.164303  ...
# 290                                 -1.052006  ...
# 291                                 -1.891703  ...
# 292                                 -0.032744  ...
# 293                                  0.544695  ...
# 294                                 -1.723008  ...
# 295                                  1.715641  ...
# 296                                  0.049950  ...
# 297                                  0.557454  ...
# 298                                  0.544695  ...
# 299                                  0.898625  ...
# 300                                  1.715641  ...
# 301                                  0.133589  ...
# 302                                  0.454441  ...
# 303                                  0.454441  ...
# 304                                  0.616993  ...
# 305                                  0.464364  ...
# 306                                  0.049950  ...
# 307                                  0.164303  ...
# 308                                  0.544695  ...
# 309                                  0.464364  ...
# 310                                  0.164303  ...
# 311                                  0.049950  ...
# 312                                  0.544695  ...
# 313                                  0.544695  ...
# 314                                  0.049950  ...
# 315                                  0.898625  ...
# 316                                  0.557454  ...
# 317                                  1.715641  ...
# 318                                  1.715641  ...
#
#      Home Average Hybrid Points Earned  Home Average Hybrid Points Lost  \
# 0                            -0.128012                         0.921959
# 1                            -0.239578                         0.710750
# 2                             0.444256                        -1.014945
# 3                             0.324158                         0.123784
# 4                            -1.999693                         0.216291
# 5                            -0.827595                         1.173282
# 6                             1.643260                        -1.636293
# 7                             0.153528                         0.438961
# 8                             0.914801                         1.836381
# 9                             0.751390                        -0.808648
# 10                            0.324158                         0.123784
# 11                           -0.737030                        -0.558144
# 12                           -0.239578                         0.710750
# 13                            0.094464                        -0.509844
# 14                            0.444256                        -1.014945
# 15                           -0.530961                         1.151997
# 16                           -0.128012                         0.921959
# 17                           -0.827595                         1.173282
# 18                           -0.530961                         1.151997
# 19                            0.477069                         0.022273
# 20                           -1.531116                         1.914970
# 21                           -0.471897                         0.409490
# 22                           -0.239578                         0.710750
# 23                            0.324158                         0.123784
# 24                            0.914801                         1.836381
# 25                           -0.530961                         1.151997
# 26                            0.153528                         0.438961
# 27                           -0.827595                         1.173282
# 28                           -0.128012                         0.921959
# 29                           -1.999693                         0.216291
# ..                                 ...                              ...
# 289                           0.094464                        -0.509844
# 290                          -1.974755                         0.082852
# 291                          -1.531116                         1.914970
# 292                           0.153528                         0.438961
# 293                          -0.530961                         1.151997
# 294                           0.751390                        -0.808648
# 295                           1.052618                        -1.175399
# 296                          -0.471897                         0.409490
# 297                          -0.737030                        -0.558144
# 298                          -0.239578                         0.710750
# 299                           1.052618                        -1.175399
# 300                          -0.471897                         0.409490
# 301                           0.153528                         0.438961
# 302                          -0.676653                        -1.008396
# 303                          -0.128012                         0.921959
# 304                           1.054586                         0.040283
# 305                           1.052618                        -1.175399
# 306                           0.324158                         0.123784
# 307                           0.751390                        -0.808648
# 308                           1.643260                        -1.636293
# 309                           0.324158                         0.123784
# 310                           1.643260                        -1.636293
# 311                           1.052618                        -1.175399
# 312                           0.751390                        -0.808648
# 313                           0.324158                         0.123784
# 314                           1.643260                        -1.636293
# 315                           1.052618                        -1.175399
# 316                           1.643260                        -1.636293
# 317                           0.751390                        -0.808648
# 318                           1.052618                        -1.175399
#
#      Home Average Hybrid Points Differential  Home Average Hybrid True Win %  \
# 0                                  -0.558648                       -0.012240
# 1                                  -0.521440                       -0.619737
# 2                                   0.810418                        1.148333
# 3                                   0.144912                       -0.279341
# 4                                  -1.400044                       -0.995714
# 5                                  -1.139169                       -1.145232
# 6                                   1.903811                        1.548307
# 7                                  -0.127802                       -0.104412
# 8                                  -0.359080                       -0.319982
# 9                                   0.901746                        0.771697
# 10                                  0.144912                       -0.279341
# 11                                 -0.186573                       -0.685790
# 12                                 -0.521440                       -0.619737
# 13                                  0.324184                        0.416718
# 14                                  0.810418                        1.148333
# 15                                 -0.937065                       -1.075545
# 16                                 -0.558648                       -0.012240
# 17                                 -1.139169                       -1.145232
# 18                                 -0.937065                       -1.075545
# 19                                  0.295856                       -0.050711
# 20                                 -1.975491                       -1.944594
# 21                                 -0.515521                       -0.820065
# 22                                 -0.521440                       -0.619737
# 23                                  0.144912                       -0.279341
# 24                                 -0.359080                       -0.319982
# 25                                 -0.937065                       -1.075545
# 26                                 -0.127802                       -0.104412
# 27                                 -1.139169                       -1.145232
# 28                                 -0.558648                       -0.012240
# 29                                 -1.400044                       -0.995714
# ..                                       ...                             ...
# 289                                 0.324184                        0.416718
# 290                                -1.315059                       -1.258449
# 291                                -1.975491                       -1.944594
# 292                                -0.127802                       -0.104412
# 293                                -0.937065                       -1.075545
# 294                                 0.901746                        0.771697
# 295                                 1.285236                        1.624456
# 296                                -0.515521                       -0.820065
# 297                                -0.186573                       -0.685790
# 298                                -0.521440                       -0.619737
# 299                                 1.285236                        1.624456
# 300                                -0.515521                       -0.820065
# 301                                -0.127802                       -0.104412
# 302                                 0.084873                        0.538653
# 303                                -0.558648                       -0.012240
# 304                                 0.658629                        0.593805
# 305                                 1.285236                        1.624456
# 306                                 0.144912                       -0.279341
# 307                                 0.901746                        0.771697
# 308                                 1.903811                        1.548307
# 309                                 0.144912                       -0.279341
# 310                                 1.903811                        1.548307
# 311                                 1.285236                        1.624456
# 312                                 0.901746                        0.771697
# 313                                 0.144912                       -0.279341
# 314                                 1.903811                        1.548307
# 315                                 1.285236                        1.624456
# 316                                 1.903811                        1.548307
# 317                                 0.901746                        0.771697
# 318                                 1.285236                        1.624456
#
#      Home Average Hybrid Map Potential %  Home Average Escort Points Earned  \
# 0                              -0.281921                          -0.647986
# 1                              -0.667250                          -1.151725
# 2                               1.167852                          -0.216376
# 3                              -0.486294                           0.128563
# 4                              -2.068059                          -1.336119
# 5                              -0.379850                          -1.258755
# 6                               1.608532                           2.168532
# 7                              -0.094579                          -0.564805
# 8                               0.022510                           1.000509
# 9                               0.799555                          -0.415894
# 10                             -0.486294                           0.128563
# 11                             -0.724730                          -0.066301
# 12                             -0.667250                          -1.151725
# 13                              0.184306                           0.593329
# 14                              1.167852                          -0.216376
# 15                             -0.614028                           0.059924
# 16                             -0.281921                          -0.647986
# 17                             -0.379850                          -1.258755
# 18                             -0.614028                           0.059924
# 19                              0.237528                          -0.996997
# 20                             -1.489001                          -0.531649
# 21                             -0.743890                           0.787030
# 22                             -0.667250                          -1.151725
# 23                             -0.486294                           0.128563
# 24                              0.022510                           1.000509
# 25                             -0.614028                           0.059924
# 26                             -0.094579                          -0.564805
# 27                             -0.379850                          -1.258755
# 28                             -0.281921                          -0.647986
# 29                             -2.068059                          -1.336119
# ..                                   ...                                ...
# 289                             0.184306                           0.593329
# 290                            -1.429392                          -0.667182
# 291                            -1.489001                          -0.531649
# 292                            -0.094579                          -0.564805
# 293                            -0.614028                           0.059924
# 294                             0.799555                          -0.415894
# 295                             1.389257                           1.539149
# 296                            -0.743890                           0.787030
# 297                            -0.724730                          -0.066301
# 298                            -0.667250                          -1.151725
# 299                             1.389257                           1.539149
# 300                            -0.743890                           0.787030
# 301                            -0.094579                          -0.564805
# 302                             0.045928                          -0.870190
# 303                            -0.281921                          -0.647986
# 304                             1.116759                           0.161719
# 305                             1.389257                           1.539149
# 306                            -0.486294                           0.128563
# 307                             0.799555                          -0.415894
# 308                             1.608532                           2.168532
# 309                            -0.486294                           0.128563
# 310                             1.608532                           2.168532
# 311                             1.389257                           1.539149
# 312                             0.799555                          -0.415894
# 313                            -0.486294                           0.128563
# 314                             1.608532                           2.168532
# 315                             1.389257                           1.539149
# 316                             1.608532                           2.168532
# 317                             0.799555                          -0.415894
# 318                             1.389257                           1.539149
#
#      Home Average Escort Points Lost  Home Average Escort Points Differential  \
# 0                           0.012385                                -0.363378
# 1                           0.045333                                -0.660770
# 2                          -0.432913                                 0.158017
# 3                          -0.112418                                 0.142382
# 4                           0.012385                                -0.740862
# 5                           0.353347                                -0.916362
# 6                          -2.476190                                 2.772329
# 7                           0.394782                                -0.562171
# 8                           0.461676                                 0.253744
# 9                          -1.290560                                 0.596767
# 10                         -0.112418                                 0.142382
# 11                          0.074786                                -0.084173
# 12                          0.045333                                -0.660770
# 13                          0.535060                                -0.016526
# 14                         -0.432913                                 0.158017
# 15                          1.751142                                -1.086438
# 16                          0.012385                                -0.363378
# 17                          0.353347                                -0.916362
# 18                          1.751142                                -1.086438
# 19                          0.195097                                -0.671619
# 20                          1.485062                                -1.240878
# 21                         -0.295629                                 0.620699
# 22                          0.045333                                -0.660770
# 23                         -0.112418                                 0.142382
# 24                          0.461676                                 0.253744
# 25                          1.751142                                -1.086438
# 26                          0.394782                                -0.562171
# 27                          0.353347                                -0.916362
# 28                          0.012385                                -0.363378
# 29                          0.012385                                -0.740862
# ..                               ...                                      ...
# 289                         0.535060                                -0.016526
# 290                         1.027284                                -1.022620
# 291                         1.485062                                -1.240878
# 292                         0.394782                                -0.562171
# 293                         1.751142                                -1.086438
# 294                        -1.290560                                 0.596767
# 295                        -0.061998                                 0.883949
# 296                        -0.295629                                 0.620699
# 297                         0.074786                                -0.084173
# 298                         0.045333                                -0.660770
# 299                        -0.061998                                 0.883949
# 300                        -0.295629                                 0.620699
# 301                         0.394782                                -0.562171
# 302                        -0.703486                                -0.027694
# 303                         0.012385                                -0.363378
# 304                         1.288871                                -0.735119
# 305                        -0.061998                                 0.883949
# 306                        -0.112418                                 0.142382
# 307                        -1.290560                                 0.596767
# 308                        -2.476190                                 2.772329
# 309                        -0.112418                                 0.142382
# 310                        -2.476190                                 2.772329
# 311                        -0.061998                                 0.883949
# 312                        -1.290560                                 0.596767
# 313                        -0.112418                                 0.142382
# 314                        -2.476190                                 2.772329
# 315                        -0.061998                                 0.883949
# 316                        -2.476190                                 2.772329
# 317                        -1.290560                                 0.596767
# 318                        -0.061998                                 0.883949
#
#      Home Average Escort True Win %  Home Average Escort Map Potential %
# 0                         -0.162836                            -0.607901
# 1                         -1.087454                            -1.261677
# 2                         -0.102351                            -0.053821
# 3                          0.203809                             0.385225
# 4                         -0.741808                            -0.563804
# 5                         -0.603540                            -1.148560
# 6                          2.486325                             2.281368
# 7                         -0.452944                            -0.533129
# 8                          0.381563                             0.824272
# 9                          0.775356                             0.680479
# 10                         0.203809                             0.385225
# 11                        -0.422074                            -0.145848
# 12                        -1.087454                            -1.261677
# 13                         0.065532                             0.761003
# 14                        -0.102351                            -0.053821
# 15                        -1.191150                            -0.931913
# 16                        -0.162836                            -0.607901
# 17                        -0.603540                            -1.148560
# 18                        -1.191150                            -0.931913
# 19                        -0.983759                            -0.805376
# 20                        -1.277559                            -1.046947
# 21                         0.744496                             0.463832
# 22                        -1.087454                            -1.261677
# 23                         0.203809                             0.385225
# 24                         0.381563                             0.824272
# 25                        -1.191150                            -0.931913
# 26                        -0.452944                            -0.533129
# 27                        -0.603540                            -1.148560
# 28                        -0.162836                            -0.607901
# 29                        -0.741808                            -0.563804
# ..                              ...                                  ...
# 289                        0.065532                             0.761003
# 290                       -1.087454                            -0.937665
# 291                       -1.277559                            -1.046947
# 292                       -0.452944                            -0.533129
# 293                       -1.191150                            -0.931913
# 294                        0.775356                             0.680479
# 295                        1.072038                             1.307414
# 296                        0.744496                             0.463832
# 297                       -0.422074                            -0.145848
# 298                       -1.087454                            -1.261677
# 299                        1.072038                             1.307414
# 300                        0.744496                             0.463832
# 301                       -0.452944                            -0.533129
# 302                        0.312430                            -0.561887
# 303                       -0.162836                            -0.607901
# 304                       -0.741808                            -0.738273
# 305                        1.072038                             1.307414
# 306                        0.203809                             0.385225
# 307                        0.775356                             0.680479
# 308                        2.486325                             2.281368
# 309                        0.203809                             0.385225
# 310                        2.486325                             2.281368
# 311                        1.072038                             1.307414
# 312                        0.775356                             0.680479
# 313                        0.203809                             0.385225
# 314                        2.486325                             2.281368
# 315                        1.072038                             1.307414
# 316                        2.486325                             2.281368
# 317                        0.775356                             0.680479
# 318                        1.072038                             1.307414
#
# [319 rows x 42 columns]

# %%
#splitting into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y
                                                   , random_state = 55
                                                   , stratify = finaldf.loc[:, 'HomeTeamWin'])

# %% [markdown]
# Here, I decided to use a variety of different models to find which one worked best. It's worth noting that the Overwatch League is rapidly changing it's ruleset, allowing teams to be terrible at the beginning of the season and do really well towards the end of the season. The stats collected are for overall season, which means games played at the beginning of the season aren't properally predicted compared to games towards the end of the season. This is something I hope to fix in the future.

# %%
rfc = RandomForestClassifier(500, random_state = 534)
rfc.fit(X_train, y_train)
print('-- Random Forest -- ')
print('Training Accuracy: ', accuracy_score(y_train, rfc.predict(X_train)))
print('Testing Accuracy: ', accuracy_score(y_test, rfc.predict(X_test)))
print('Whole Dataset: ', accuracy_score(finaldf['HomeTeamWin'],rfc.predict(finaldf.loc[:, X_train.columns])))
print('\n')

lr = LogisticRegression(random_state = 534)
lr.fit(X_train, y_train)
print('-- Logistic Regression -- ')
print('Training Accuracy: ', accuracy_score(y_train, lr.predict(X_train)))
print('Testing Accuracy: ', accuracy_score(y_test, lr.predict(X_test)))
print('Whole Dataset: ', accuracy_score(finaldf['HomeTeamWin'],lr.predict(finaldf.loc[:, X_train.columns])))
print('\n')

knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
print('-- K Nearest Neighbors -- ')
print('Training Accuracy: ', accuracy_score(y_train, knn.predict(X_train)))
print('Testing Accuracy: ', accuracy_score(y_test, knn.predict(X_test)))
print('Whole Dataset: ', accuracy_score(finaldf['HomeTeamWin'],knn.predict(finaldf.loc[:, X_train.columns])))
print('\n')

sv = SVC()
sv.fit(X_train, y_train)
print('-- SVC -- ')
print('Training Accuracy: ', accuracy_score(y_train, sv.predict(X_train)))
print('Testing Accuracy: ', accuracy_score(y_test, sv.predict(X_test)))
print('Whole Dataset: ', accuracy_score(finaldf['HomeTeamWin'],sv.predict(finaldf.loc[:, X_train.columns])))
print('\n')

xgboost = xgb.XGBClassifier(seed = 82)
xgboost.fit(X_train, y_train)
print('-- XGBoost --')
print('Training Accuracy: ', accuracy_score(y_train, xgboost.predict(X_train)))
print('Testing Accuracy: ', accuracy_score(y_test, xgboost.predict(X_test)))
print('Whole Dataset: ', accuracy_score(finaldf['HomeTeamWin'],xgboost.predict(finaldf.loc[:, X_train.columns])))
# Out:
# -- Random Forest --
# Training Accuracy:  0.9623430962343096
# Testing Accuracy:  0.775
# Whole Dataset:  0.6927899686520376
#
#
# -- Logistic Regression --
# Training Accuracy:  0.698744769874477
# Testing Accuracy:  0.775
# Whole Dataset:  0.6112852664576802
#
#
# -- K Nearest Neighbors --
# Training Accuracy:  0.7782426778242678
# Testing Accuracy:  0.6875
# Whole Dataset:  0.670846394984326
#
#
# -- SVC --
# Training Accuracy:  0.8368200836820083
# Testing Accuracy:  0.7125
# Whole Dataset:  0.5297805642633229
#
#
# -- XGBoost --
# Training Accuracy:  0.8619246861924686
# Testing Accuracy:  0.7125
# Whole Dataset:  0.6300940438871473
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %% [markdown]
# As seen, each of the models vary in it's predictions. The testing accuracy does not go above 80%, as well as the whole dataset accuracy being significantly worse (this is expected since the overall season is much more in flux). This is overall very good accuracy, as the Overwatch League is in such a constant state of flux that anything above 50% is considered good. This is also very good results, as it shows that we have not run into an overfitting problem yet.
#
# Ideally, with more relavent features, the accuracy can go up. Furthermore, in previous seasons the league was run on a stage-by-stage basis, meaning every 7 weeks the game patch would change. This would introduce the possibility that teams do much better, since the overall way to play changes drastically. However in 2019, while the game patch will continue to change, there will no longer be stages. As such, momentum shifts may be limited, which would in turn better standarize our data and allow better accuracy.

# %%
#created a function that would choose any two teams from the overwatch league and determine the winner. 
def test_predict(away, home):
    
    #turn id back into name
    def convert_prediction(prediction):
        if prediction[0] == 1:
            #Home Won
            return ID_TO_NAME.get(testrow[1])
        if prediction[0] == 0:
            #Away Won
            return ID_TO_NAME.get(testrow[0])


    #create test data series
    newcol = ["away", "home"]
    
    #enter names of teams to get
    testrow = pd.Series([away, home], index=newcol)

    #get all stats for each team
    awayrow = get_team_stats(testrow[0])
    homerow = get_team_stats(testrow[1])

    #convert columns to proper team placement
    awayrow = awayrow.rename(lambda x: "Away " + x)
    homerow = homerow.rename(lambda x: "Home " + x)

    #turn name into id
    for name, team in ID_TO_NAME.items():
        if team == testrow[0]:
            testrow[0] = name
        if team == testrow[1]:
            testrow[1] = name
    testrow = pd.concat([testrow, awayrow, homerow])
    testrow = testrow[~testrow.index.str.contains("Rank")]

    #predictions
    rfcprediction = rfc.predict([testrow])
    lrprediction = lr.predict([testrow])
    knnprediction = knn.predict([testrow])
    svprediction = sv.predict([testrow])
    
    print("Random Forest Prediction: ", convert_prediction(rfcprediction))
    print(" ")
    print("Logistic Regression Prediction: ", convert_prediction(lrprediction))
    print(" ")
    print("K Nearest Neighbors Prediction: ", convert_prediction(knnprediction))
    print(" ")
    print("SVC Prediction: ", convert_prediction(svprediction))
    print(" ")


test_predict("San Francisco Shock", "Vancouver Titans")
# Out:
# Random Forest Prediction:  San Francisco Shock
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  San Francisco Shock
#
# SVC Prediction:  Vancouver Titans

# %% [markdown]
# One note worth mentioning is how being the home team has a massive impact on whether teams will win or not. While for teams far enough away in the standings, this does not impact them, teams that are close to each other in the standings will often be chosen based on if they are home or away. While the features below do not prove that hypothesis, general testing shows it (done below).

# %%
teams = ["Atlanta Reign",
    "Boston Uprising",
    "Chengdu Hunters",
    "Dallas Fuel",
    "Florida Mayhem",
    "Guangzhou Charge",
    "Hangzhou Spark",
    "Houston Outlaws",
    "London Spitfire",
    "Los Angeles Gladiators",
    "Los Angeles Valiant",
    "New York Excelsior",
    "Paris Eternal",
    "Philadelphia Fusion",
    "San Francisco Shock",
    "Seoul Dynasty",
    "Shanghai Dragons",
    "Toronto Defiant",
    "Vancouver Titans",
    "Washington Justice"
        ]

for home in teams:
    for away in teams:
        print(away, "vs", home)
        print("=========================")
        
        test_predict(away, home)
# Out:
# Atlanta Reign vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Atlanta Reign
#
# Boston Uprising vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Atlanta Reign
#
# Chengdu Hunters vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Chengdu Hunters
#
# SVC Prediction:  Atlanta Reign
#
# Dallas Fuel vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Atlanta Reign
#
# Florida Mayhem vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Atlanta Reign
#
# Guangzhou Charge vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Guangzhou Charge
#
# SVC Prediction:  Atlanta Reign
#
# Hangzhou Spark vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Atlanta Reign
#
# Houston Outlaws vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Atlanta Reign
#
# London Spitfire vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  Atlanta Reign
#
# Los Angeles Gladiators vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Atlanta Reign
#
# Los Angeles Valiant vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Los Angeles Valiant
#
# SVC Prediction:  Atlanta Reign
#
# New York Excelsior vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  New York Excelsior
#
# SVC Prediction:  Atlanta Reign
#
# Paris Eternal vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Paris Eternal
#
# SVC Prediction:  Atlanta Reign
#
# Philadelphia Fusion vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Atlanta Reign
#
# San Francisco Shock vs Atlanta Reign
# =========================
# Random Forest Prediction:  San Francisco Shock
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  San Francisco Shock
#
# SVC Prediction:  Atlanta Reign
#
# Seoul Dynasty vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Seoul Dynasty
#
# SVC Prediction:  Atlanta Reign
#
# Shanghai Dragons vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Shanghai Dragons
#
# SVC Prediction:  Atlanta Reign
#
# Toronto Defiant vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Atlanta Reign
#
# Vancouver Titans vs Atlanta Reign
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Atlanta Reign
#
# Washington Justice vs Atlanta Reign
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Atlanta Reign
#
# Atlanta Reign vs Boston Uprising
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Boston Uprising
#
# Boston Uprising vs Boston Uprising
# =========================
# Random Forest Prediction:  Boston Uprising
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Boston Uprising
#
# SVC Prediction:  Boston Uprising
#
# Chengdu Hunters vs Boston Uprising
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Chengdu Hunters
#
# SVC Prediction:  Boston Uprising
#
# Dallas Fuel vs Boston Uprising
# =========================
# Random Forest Prediction:  Boston Uprising
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Boston Uprising
#
# SVC Prediction:  Boston Uprising
#
# Florida Mayhem vs Boston Uprising
# =========================
# Random Forest Prediction:  Boston Uprising
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Boston Uprising
#
# SVC Prediction:  Boston Uprising
#
# Guangzhou Charge vs Boston Uprising
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Guangzhou Charge
#
# SVC Prediction:  Boston Uprising
#
# Hangzhou Spark vs Boston Uprising
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Boston Uprising
#
# Houston Outlaws vs Boston Uprising
# =========================
# Random Forest Prediction:  Boston Uprising
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Boston Uprising
#
# SVC Prediction:  Boston Uprising
#
# London Spitfire vs Boston Uprising
# =========================
# Random Forest Prediction:  London Spitfire
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  Boston Uprising
#
# Los Angeles Gladiators vs Boston Uprising
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Boston Uprising
#
# Los Angeles Valiant vs Boston Uprising
# =========================
# Random Forest Prediction:  Los Angeles Valiant
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Los Angeles Valiant
#
# SVC Prediction:  Boston Uprising
#
# New York Excelsior vs Boston Uprising
# =========================
# Random Forest Prediction:  New York Excelsior
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  New York Excelsior
#
# SVC Prediction:  Boston Uprising
#
# Paris Eternal vs Boston Uprising
# =========================
# Random Forest Prediction:  Boston Uprising
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Paris Eternal
#
# SVC Prediction:  Boston Uprising
#
# Philadelphia Fusion vs Boston Uprising
# =========================
# Random Forest Prediction:  Boston Uprising
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Boston Uprising
#
# SVC Prediction:  Boston Uprising
#
# San Francisco Shock vs Boston Uprising
# =========================
# Random Forest Prediction:  San Francisco Shock
#
# Logistic Regression Prediction:  San Francisco Shock
#
# K Nearest Neighbors Prediction:  San Francisco Shock
#
# SVC Prediction:  Boston Uprising
#
# Seoul Dynasty vs Boston Uprising
# =========================
# Random Forest Prediction:  Seoul Dynasty
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Seoul Dynasty
#
# SVC Prediction:  Boston Uprising
#
# Shanghai Dragons vs Boston Uprising
# =========================
# Random Forest Prediction:  Shanghai Dragons
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Shanghai Dragons
#
# SVC Prediction:  Boston Uprising
#
# Toronto Defiant vs Boston Uprising
# =========================
# Random Forest Prediction:  Boston Uprising
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Boston Uprising
#
# SVC Prediction:  Boston Uprising
#
# Vancouver Titans vs Boston Uprising
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Boston Uprising
#
# Washington Justice vs Boston Uprising
# =========================
# Random Forest Prediction:  Boston Uprising
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Boston Uprising
#
# SVC Prediction:  Boston Uprising
#
# Atlanta Reign vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Chengdu Hunters
#
# Boston Uprising vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Chengdu Hunters
#
# SVC Prediction:  Chengdu Hunters
#
# Chengdu Hunters vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Chengdu Hunters
#
# SVC Prediction:  Chengdu Hunters
#
# Dallas Fuel vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Chengdu Hunters
#
# SVC Prediction:  Chengdu Hunters
#
# Florida Mayhem vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Chengdu Hunters
#
# SVC Prediction:  Chengdu Hunters
#
# Guangzhou Charge vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Guangzhou Charge
#
# SVC Prediction:  Chengdu Hunters
#
# Hangzhou Spark vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Chengdu Hunters
#
# Houston Outlaws vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Chengdu Hunters
#
# SVC Prediction:  Chengdu Hunters
#
# London Spitfire vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  Chengdu Hunters
#
# Los Angeles Gladiators vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Chengdu Hunters
#
# Los Angeles Valiant vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Los Angeles Valiant
#
# SVC Prediction:  Chengdu Hunters
#
# New York Excelsior vs Chengdu Hunters
# =========================
# Random Forest Prediction:  New York Excelsior
#
# Logistic Regression Prediction:  New York Excelsior
#
# K Nearest Neighbors Prediction:  New York Excelsior
#
# SVC Prediction:  Chengdu Hunters
#
# Paris Eternal vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Paris Eternal
#
# SVC Prediction:  Chengdu Hunters
#
# Philadelphia Fusion vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Chengdu Hunters
#
# SVC Prediction:  Chengdu Hunters
#
# San Francisco Shock vs Chengdu Hunters
# =========================
# Random Forest Prediction:  San Francisco Shock
#
# Logistic Regression Prediction:  San Francisco Shock
#
# K Nearest Neighbors Prediction:  San Francisco Shock
#
# SVC Prediction:  Chengdu Hunters
#
# Seoul Dynasty vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Seoul Dynasty
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Seoul Dynasty
#
# SVC Prediction:  Chengdu Hunters
#
# Shanghai Dragons vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Shanghai Dragons
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Shanghai Dragons
#
# SVC Prediction:  Chengdu Hunters
#
# Toronto Defiant vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Chengdu Hunters
#
# SVC Prediction:  Chengdu Hunters
#
# Vancouver Titans vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Chengdu Hunters
#
# Washington Justice vs Chengdu Hunters
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Washington Justice
#
# SVC Prediction:  Chengdu Hunters
#
# Atlanta Reign vs Dallas Fuel
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Dallas Fuel
#
# Boston Uprising vs Dallas Fuel
# =========================
# Random Forest Prediction:  Dallas Fuel
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Boston Uprising
#
# SVC Prediction:  Dallas Fuel
#
# Chengdu Hunters vs Dallas Fuel
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Chengdu Hunters
#
# SVC Prediction:  Dallas Fuel
#
# Dallas Fuel vs Dallas Fuel
# =========================
# Random Forest Prediction:  Dallas Fuel
#
# Logistic Regression Prediction:  Dallas Fuel
#
# K Nearest Neighbors Prediction:  Dallas Fuel
#
# SVC Prediction:  Dallas Fuel
#
# Florida Mayhem vs Dallas Fuel
# =========================
# Random Forest Prediction:  Dallas Fuel
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Florida Mayhem
#
# SVC Prediction:  Dallas Fuel
#
# Guangzhou Charge vs Dallas Fuel
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Guangzhou Charge
#
# SVC Prediction:  Dallas Fuel
#
# Hangzhou Spark vs Dallas Fuel
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Dallas Fuel
#
# Houston Outlaws vs Dallas Fuel
# =========================
# Random Forest Prediction:  Dallas Fuel
#
# Logistic Regression Prediction:  Houston Outlaws
#
# K Nearest Neighbors Prediction:  Dallas Fuel
#
# SVC Prediction:  Dallas Fuel
#
# London Spitfire vs Dallas Fuel
# =========================
# Random Forest Prediction:  London Spitfire
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  Dallas Fuel
#
# Los Angeles Gladiators vs Dallas Fuel
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Dallas Fuel
#
# Los Angeles Valiant vs Dallas Fuel
# =========================
# Random Forest Prediction:  Los Angeles Valiant
#
# Logistic Regression Prediction:  Los Angeles Valiant
#
# K Nearest Neighbors Prediction:  Los Angeles Valiant
#
# SVC Prediction:  Dallas Fuel
#
# New York Excelsior vs Dallas Fuel
# =========================
# Random Forest Prediction:  New York Excelsior
#
# Logistic Regression Prediction:  New York Excelsior
#
# K Nearest Neighbors Prediction:  New York Excelsior
#
# SVC Prediction:  Dallas Fuel
#
# Paris Eternal vs Dallas Fuel
# =========================
# Random Forest Prediction:  Dallas Fuel
#
# Logistic Regression Prediction:  Paris Eternal
#
# K Nearest Neighbors Prediction:  Paris Eternal
#
# SVC Prediction:  Dallas Fuel
#
# Philadelphia Fusion vs Dallas Fuel
# =========================
# Random Forest Prediction:  Philadelphia Fusion
#
# Logistic Regression Prediction:  Philadelphia Fusion
#
# K Nearest Neighbors Prediction:  Dallas Fuel
#
# SVC Prediction:  Dallas Fuel
#
# San Francisco Shock vs Dallas Fuel
# =========================
# Random Forest Prediction:  San Francisco Shock
#
# Logistic Regression Prediction:  San Francisco Shock
#
# K Nearest Neighbors Prediction:  San Francisco Shock
#
# SVC Prediction:  Dallas Fuel
#
# Seoul Dynasty vs Dallas Fuel
# =========================
# Random Forest Prediction:  Seoul Dynasty
#
# Logistic Regression Prediction:  Seoul Dynasty
#
# K Nearest Neighbors Prediction:  Seoul Dynasty
#
# SVC Prediction:  Dallas Fuel
#
# Shanghai Dragons vs Dallas Fuel
# =========================
# Random Forest Prediction:  Shanghai Dragons
#
# Logistic Regression Prediction:  Shanghai Dragons
#
# K Nearest Neighbors Prediction:  Shanghai Dragons
#
# SVC Prediction:  Dallas Fuel
#
# Toronto Defiant vs Dallas Fuel
# =========================
# Random Forest Prediction:  Dallas Fuel
#
# Logistic Regression Prediction:  Toronto Defiant
#
# K Nearest Neighbors Prediction:  Toronto Defiant
#
# SVC Prediction:  Dallas Fuel
#
# Vancouver Titans vs Dallas Fuel
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Dallas Fuel
#
# Washington Justice vs Dallas Fuel
# =========================
# Random Forest Prediction:  Dallas Fuel
#
# Logistic Regression Prediction:  Washington Justice
#
# K Nearest Neighbors Prediction:  Washington Justice
#
# SVC Prediction:  Dallas Fuel
#
# Atlanta Reign vs Florida Mayhem
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Florida Mayhem
#
# Boston Uprising vs Florida Mayhem
# =========================
# Random Forest Prediction:  Florida Mayhem
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Florida Mayhem
#
# SVC Prediction:  Florida Mayhem
#
# Chengdu Hunters vs Florida Mayhem
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Chengdu Hunters
#
# SVC Prediction:  Florida Mayhem
#
# Dallas Fuel vs Florida Mayhem
# =========================
# Random Forest Prediction:  Florida Mayhem
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Florida Mayhem
#
# SVC Prediction:  Florida Mayhem
#
# Florida Mayhem vs Florida Mayhem
# =========================
# Random Forest Prediction:  Florida Mayhem
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Florida Mayhem
#
# SVC Prediction:  Florida Mayhem
#
# Guangzhou Charge vs Florida Mayhem
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Guangzhou Charge
#
# SVC Prediction:  Florida Mayhem
#
# Hangzhou Spark vs Florida Mayhem
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Florida Mayhem
#
# Houston Outlaws vs Florida Mayhem
# =========================
# Random Forest Prediction:  Florida Mayhem
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Florida Mayhem
#
# SVC Prediction:  Florida Mayhem
#
# London Spitfire vs Florida Mayhem
# =========================
# Random Forest Prediction:  London Spitfire
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  Florida Mayhem
#
# Los Angeles Gladiators vs Florida Mayhem
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Florida Mayhem
#
# Los Angeles Valiant vs Florida Mayhem
# =========================
# Random Forest Prediction:  Florida Mayhem
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Los Angeles Valiant
#
# SVC Prediction:  Florida Mayhem
#
# New York Excelsior vs Florida Mayhem
# =========================
# Random Forest Prediction:  New York Excelsior
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  New York Excelsior
#
# SVC Prediction:  Florida Mayhem
#
# Paris Eternal vs Florida Mayhem
# =========================
# Random Forest Prediction:  Florida Mayhem
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Paris Eternal
#
# SVC Prediction:  Florida Mayhem
#
# Philadelphia Fusion vs Florida Mayhem
# =========================
# Random Forest Prediction:  Florida Mayhem
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Florida Mayhem
#
# SVC Prediction:  Florida Mayhem
#
# San Francisco Shock vs Florida Mayhem
# =========================
# Random Forest Prediction:  San Francisco Shock
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  San Francisco Shock
#
# SVC Prediction:  Florida Mayhem
#
# Seoul Dynasty vs Florida Mayhem
# =========================
# Random Forest Prediction:  Seoul Dynasty
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Seoul Dynasty
#
# SVC Prediction:  Florida Mayhem
#
# Shanghai Dragons vs Florida Mayhem
# =========================
# Random Forest Prediction:  Shanghai Dragons
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Shanghai Dragons
#
# SVC Prediction:  Florida Mayhem
#
# Toronto Defiant vs Florida Mayhem
# =========================
# Random Forest Prediction:  Florida Mayhem
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Florida Mayhem
#
# SVC Prediction:  Florida Mayhem
#
# Vancouver Titans vs Florida Mayhem
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Florida Mayhem
#
# Washington Justice vs Florida Mayhem
# =========================
# Random Forest Prediction:  Florida Mayhem
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Florida Mayhem
#
# SVC Prediction:  Florida Mayhem
#
# Atlanta Reign vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Guangzhou Charge
#
# Boston Uprising vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Guangzhou Charge
#
# SVC Prediction:  Guangzhou Charge
#
# Chengdu Hunters vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Chengdu Hunters
#
# SVC Prediction:  Guangzhou Charge
#
# Dallas Fuel vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Guangzhou Charge
#
# SVC Prediction:  Guangzhou Charge
#
# Florida Mayhem vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Guangzhou Charge
#
# SVC Prediction:  Guangzhou Charge
#
# Guangzhou Charge vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Guangzhou Charge
#
# SVC Prediction:  Guangzhou Charge
#
# Hangzhou Spark vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Guangzhou Charge
#
# Houston Outlaws vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Guangzhou Charge
#
# SVC Prediction:  Guangzhou Charge
#
# London Spitfire vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  Guangzhou Charge
#
# Los Angeles Gladiators vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Guangzhou Charge
#
# Los Angeles Valiant vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Los Angeles Valiant
#
# SVC Prediction:  Guangzhou Charge
#
# New York Excelsior vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  New York Excelsior
#
# SVC Prediction:  Guangzhou Charge
#
# Paris Eternal vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Paris Eternal
#
# SVC Prediction:  Guangzhou Charge
#
# Philadelphia Fusion vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Guangzhou Charge
#
# SVC Prediction:  Guangzhou Charge
#
# San Francisco Shock vs Guangzhou Charge
# =========================
# Random Forest Prediction:  San Francisco Shock
#
# Logistic Regression Prediction:  San Francisco Shock
#
# K Nearest Neighbors Prediction:  San Francisco Shock
#
# SVC Prediction:  Guangzhou Charge
#
# Seoul Dynasty vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Seoul Dynasty
#
# SVC Prediction:  Guangzhou Charge
#
# Shanghai Dragons vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Shanghai Dragons
#
# SVC Prediction:  Guangzhou Charge
#
# Toronto Defiant vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Toronto Defiant
#
# SVC Prediction:  Guangzhou Charge
#
# Vancouver Titans vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Guangzhou Charge
#
# Washington Justice vs Guangzhou Charge
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Washington Justice
#
# SVC Prediction:  Guangzhou Charge
#
# Atlanta Reign vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Hangzhou Spark
#
# Boston Uprising vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Hangzhou Spark
#
# Chengdu Hunters vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Chengdu Hunters
#
# SVC Prediction:  Hangzhou Spark
#
# Dallas Fuel vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Hangzhou Spark
#
# Florida Mayhem vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Hangzhou Spark
#
# Guangzhou Charge vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Guangzhou Charge
#
# SVC Prediction:  Hangzhou Spark
#
# Hangzhou Spark vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Hangzhou Spark
#
# Houston Outlaws vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Hangzhou Spark
#
# London Spitfire vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  Hangzhou Spark
#
# Los Angeles Gladiators vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Hangzhou Spark
#
# Los Angeles Valiant vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Los Angeles Valiant
#
# SVC Prediction:  Hangzhou Spark
#
# New York Excelsior vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  New York Excelsior
#
# SVC Prediction:  Hangzhou Spark
#
# Paris Eternal vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Paris Eternal
#
# SVC Prediction:  Hangzhou Spark
#
# Philadelphia Fusion vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Hangzhou Spark
#
# San Francisco Shock vs Hangzhou Spark
# =========================
# Random Forest Prediction:  San Francisco Shock
#
# Logistic Regression Prediction:  San Francisco Shock
#
# K Nearest Neighbors Prediction:  San Francisco Shock
#
# SVC Prediction:  Hangzhou Spark
#
# Seoul Dynasty vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Seoul Dynasty
#
# SVC Prediction:  Hangzhou Spark
#
# Shanghai Dragons vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Shanghai Dragons
#
# SVC Prediction:  Hangzhou Spark
#
# Toronto Defiant vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Hangzhou Spark
#
# Vancouver Titans vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Hangzhou Spark
#
# Washington Justice vs Hangzhou Spark
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Hangzhou Spark
#
# Atlanta Reign vs Houston Outlaws
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Houston Outlaws
#
# Boston Uprising vs Houston Outlaws
# =========================
# Random Forest Prediction:  Houston Outlaws
#
# Logistic Regression Prediction:  Houston Outlaws
#
# K Nearest Neighbors Prediction:  Boston Uprising
#
# SVC Prediction:  Houston Outlaws
#
# Chengdu Hunters vs Houston Outlaws
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Chengdu Hunters
#
# SVC Prediction:  Houston Outlaws
#
# Dallas Fuel vs Houston Outlaws
# =========================
# Random Forest Prediction:  Houston Outlaws
#
# Logistic Regression Prediction:  Houston Outlaws
#
# K Nearest Neighbors Prediction:  Houston Outlaws
#
# SVC Prediction:  Houston Outlaws
#
# Florida Mayhem vs Houston Outlaws
# =========================
# Random Forest Prediction:  Houston Outlaws
#
# Logistic Regression Prediction:  Houston Outlaws
#
# K Nearest Neighbors Prediction:  Florida Mayhem
#
# SVC Prediction:  Houston Outlaws
#
# Guangzhou Charge vs Houston Outlaws
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Guangzhou Charge
#
# SVC Prediction:  Houston Outlaws
#
# Hangzhou Spark vs Houston Outlaws
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Houston Outlaws
#
# Houston Outlaws vs Houston Outlaws
# =========================
# Random Forest Prediction:  Houston Outlaws
#
# Logistic Regression Prediction:  Houston Outlaws
#
# K Nearest Neighbors Prediction:  Houston Outlaws
#
# SVC Prediction:  Houston Outlaws
#
# London Spitfire vs Houston Outlaws
# =========================
# Random Forest Prediction:  Houston Outlaws
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  Houston Outlaws
#
# Los Angeles Gladiators vs Houston Outlaws
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Houston Outlaws
#
# Los Angeles Valiant vs Houston Outlaws
# =========================
# Random Forest Prediction:  Houston Outlaws
#
# Logistic Regression Prediction:  Los Angeles Valiant
#
# K Nearest Neighbors Prediction:  Los Angeles Valiant
#
# SVC Prediction:  Houston Outlaws
#
# New York Excelsior vs Houston Outlaws
# =========================
# Random Forest Prediction:  New York Excelsior
#
# Logistic Regression Prediction:  New York Excelsior
#
# K Nearest Neighbors Prediction:  New York Excelsior
#
# SVC Prediction:  Houston Outlaws
#
# Paris Eternal vs Houston Outlaws
# =========================
# Random Forest Prediction:  Houston Outlaws
#
# Logistic Regression Prediction:  Houston Outlaws
#
# K Nearest Neighbors Prediction:  Paris Eternal
#
# SVC Prediction:  Houston Outlaws
#
# Philadelphia Fusion vs Houston Outlaws
# =========================
# Random Forest Prediction:  Houston Outlaws
#
# Logistic Regression Prediction:  Houston Outlaws
#
# K Nearest Neighbors Prediction:  Philadelphia Fusion
#
# SVC Prediction:  Houston Outlaws
#
# San Francisco Shock vs Houston Outlaws
# =========================
# Random Forest Prediction:  San Francisco Shock
#
# Logistic Regression Prediction:  San Francisco Shock
#
# K Nearest Neighbors Prediction:  San Francisco Shock
#
# SVC Prediction:  Houston Outlaws
#
# Seoul Dynasty vs Houston Outlaws
# =========================
# Random Forest Prediction:  Seoul Dynasty
#
# Logistic Regression Prediction:  Seoul Dynasty
#
# K Nearest Neighbors Prediction:  Seoul Dynasty
#
# SVC Prediction:  Houston Outlaws
#
# Shanghai Dragons vs Houston Outlaws
# =========================
# Random Forest Prediction:  Shanghai Dragons
#
# Logistic Regression Prediction:  Shanghai Dragons
#
# K Nearest Neighbors Prediction:  Shanghai Dragons
#
# SVC Prediction:  Houston Outlaws
#
# Toronto Defiant vs Houston Outlaws
# =========================
# Random Forest Prediction:  Houston Outlaws
#
# Logistic Regression Prediction:  Houston Outlaws
#
# K Nearest Neighbors Prediction:  Toronto Defiant
#
# SVC Prediction:  Houston Outlaws
#
# Vancouver Titans vs Houston Outlaws
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Houston Outlaws
#
# Washington Justice vs Houston Outlaws
# =========================
# Random Forest Prediction:  Houston Outlaws
#
# Logistic Regression Prediction:  Houston Outlaws
#
# K Nearest Neighbors Prediction:  Washington Justice
#
# SVC Prediction:  Houston Outlaws
#
# Atlanta Reign vs London Spitfire
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  London Spitfire
#
# Boston Uprising vs London Spitfire
# =========================
# Random Forest Prediction:  London Spitfire
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  London Spitfire
#
# Chengdu Hunters vs London Spitfire
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  London Spitfire
#
# Dallas Fuel vs London Spitfire
# =========================
# Random Forest Prediction:  London Spitfire
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  London Spitfire
#
# Florida Mayhem vs London Spitfire
# =========================
# Random Forest Prediction:  London Spitfire
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  London Spitfire
#
# Guangzhou Charge vs London Spitfire
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  London Spitfire
#
# Hangzhou Spark vs London Spitfire
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  London Spitfire
#
# Houston Outlaws vs London Spitfire
# =========================
# Random Forest Prediction:  London Spitfire
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  London Spitfire
#
# London Spitfire vs London Spitfire
# =========================
# Random Forest Prediction:  London Spitfire
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  London Spitfire
#
# Los Angeles Gladiators vs London Spitfire
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  London Spitfire
#
# Los Angeles Valiant vs London Spitfire
# =========================
# Random Forest Prediction:  London Spitfire
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  London Spitfire
#
# New York Excelsior vs London Spitfire
# =========================
# Random Forest Prediction:  New York Excelsior
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  New York Excelsior
#
# SVC Prediction:  London Spitfire
#
# Paris Eternal vs London Spitfire
# =========================
# Random Forest Prediction:  London Spitfire
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  London Spitfire
#
# Philadelphia Fusion vs London Spitfire
# =========================
# Random Forest Prediction:  London Spitfire
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  London Spitfire
#
# San Francisco Shock vs London Spitfire
# =========================
# Random Forest Prediction:  San Francisco Shock
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  San Francisco Shock
#
# SVC Prediction:  London Spitfire
#
# Seoul Dynasty vs London Spitfire
# =========================
# Random Forest Prediction:  Seoul Dynasty
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  London Spitfire
#
# Shanghai Dragons vs London Spitfire
# =========================
# Random Forest Prediction:  Shanghai Dragons
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  London Spitfire
#
# Toronto Defiant vs London Spitfire
# =========================
# Random Forest Prediction:  London Spitfire
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  London Spitfire
#
# Vancouver Titans vs London Spitfire
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  London Spitfire
#
# Washington Justice vs London Spitfire
# =========================
# Random Forest Prediction:  London Spitfire
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  London Spitfire
#
# Atlanta Reign vs Los Angeles Gladiators
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Los Angeles Gladiators
#
# Boston Uprising vs Los Angeles Gladiators
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Los Angeles Gladiators
#
# Chengdu Hunters vs Los Angeles Gladiators
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Los Angeles Gladiators
#
# Dallas Fuel vs Los Angeles Gladiators
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Los Angeles Gladiators
#
# Florida Mayhem vs Los Angeles Gladiators
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Los Angeles Gladiators
#
# Guangzhou Charge vs Los Angeles Gladiators
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Los Angeles Gladiators
#
# Hangzhou Spark vs Los Angeles Gladiators
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Los Angeles Gladiators
#
# Houston Outlaws vs Los Angeles Gladiators
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Los Angeles Gladiators
#
# London Spitfire vs Los Angeles Gladiators
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Los Angeles Gladiators
#
# Los Angeles Gladiators vs Los Angeles Gladiators
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Los Angeles Gladiators
#
# Los Angeles Valiant vs Los Angeles Gladiators
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Los Angeles Gladiators
#
# New York Excelsior vs Los Angeles Gladiators
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Los Angeles Gladiators
#
# Paris Eternal vs Los Angeles Gladiators
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Los Angeles Gladiators
#
# Philadelphia Fusion vs Los Angeles Gladiators
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Los Angeles Gladiators
#
# San Francisco Shock vs Los Angeles Gladiators
# =========================
# Random Forest Prediction:  San Francisco Shock
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  San Francisco Shock
#
# SVC Prediction:  Los Angeles Gladiators
#
# Seoul Dynasty vs Los Angeles Gladiators
# =========================
# ...
# =========================
# Random Forest Prediction:  Shanghai Dragons
#
# Logistic Regression Prediction:  Shanghai Dragons
#
# K Nearest Neighbors Prediction:  Shanghai Dragons
#
# SVC Prediction:  Shanghai Dragons
#
# Toronto Defiant vs Shanghai Dragons
# =========================
# Random Forest Prediction:  Shanghai Dragons
#
# Logistic Regression Prediction:  Shanghai Dragons
#
# K Nearest Neighbors Prediction:  Shanghai Dragons
#
# SVC Prediction:  Shanghai Dragons
#
# Vancouver Titans vs Shanghai Dragons
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Shanghai Dragons
#
# Washington Justice vs Shanghai Dragons
# =========================
# Random Forest Prediction:  Shanghai Dragons
#
# Logistic Regression Prediction:  Shanghai Dragons
#
# K Nearest Neighbors Prediction:  Shanghai Dragons
#
# SVC Prediction:  Shanghai Dragons
#
# Atlanta Reign vs Toronto Defiant
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Toronto Defiant
#
# Boston Uprising vs Toronto Defiant
# =========================
# Random Forest Prediction:  Toronto Defiant
#
# Logistic Regression Prediction:  Boston Uprising
#
# K Nearest Neighbors Prediction:  Boston Uprising
#
# SVC Prediction:  Toronto Defiant
#
# Chengdu Hunters vs Toronto Defiant
# =========================
# Random Forest Prediction:  Toronto Defiant
#
# Logistic Regression Prediction:  Chengdu Hunters
#
# K Nearest Neighbors Prediction:  Chengdu Hunters
#
# SVC Prediction:  Toronto Defiant
#
# Dallas Fuel vs Toronto Defiant
# =========================
# Random Forest Prediction:  Toronto Defiant
#
# Logistic Regression Prediction:  Dallas Fuel
#
# K Nearest Neighbors Prediction:  Toronto Defiant
#
# SVC Prediction:  Toronto Defiant
#
# Florida Mayhem vs Toronto Defiant
# =========================
# Random Forest Prediction:  Toronto Defiant
#
# Logistic Regression Prediction:  Florida Mayhem
#
# K Nearest Neighbors Prediction:  Florida Mayhem
#
# SVC Prediction:  Toronto Defiant
#
# Guangzhou Charge vs Toronto Defiant
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Guangzhou Charge
#
# K Nearest Neighbors Prediction:  Guangzhou Charge
#
# SVC Prediction:  Toronto Defiant
#
# Hangzhou Spark vs Toronto Defiant
# =========================
# Random Forest Prediction:  Hangzhou Spark
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Toronto Defiant
#
# Houston Outlaws vs Toronto Defiant
# =========================
# Random Forest Prediction:  Toronto Defiant
#
# Logistic Regression Prediction:  Houston Outlaws
#
# K Nearest Neighbors Prediction:  Toronto Defiant
#
# SVC Prediction:  Toronto Defiant
#
# London Spitfire vs Toronto Defiant
# =========================
# Random Forest Prediction:  London Spitfire
#
# Logistic Regression Prediction:  London Spitfire
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  Toronto Defiant
#
# Los Angeles Gladiators vs Toronto Defiant
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Los Angeles Gladiators
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Toronto Defiant
#
# Los Angeles Valiant vs Toronto Defiant
# =========================
# Random Forest Prediction:  Toronto Defiant
#
# Logistic Regression Prediction:  Los Angeles Valiant
#
# K Nearest Neighbors Prediction:  Los Angeles Valiant
#
# SVC Prediction:  Toronto Defiant
#
# New York Excelsior vs Toronto Defiant
# =========================
# Random Forest Prediction:  New York Excelsior
#
# Logistic Regression Prediction:  New York Excelsior
#
# K Nearest Neighbors Prediction:  New York Excelsior
#
# SVC Prediction:  Toronto Defiant
#
# Paris Eternal vs Toronto Defiant
# =========================
# Random Forest Prediction:  Toronto Defiant
#
# Logistic Regression Prediction:  Paris Eternal
#
# K Nearest Neighbors Prediction:  Paris Eternal
#
# SVC Prediction:  Toronto Defiant
#
# Philadelphia Fusion vs Toronto Defiant
# =========================
# Random Forest Prediction:  Toronto Defiant
#
# Logistic Regression Prediction:  Philadelphia Fusion
#
# K Nearest Neighbors Prediction:  Toronto Defiant
#
# SVC Prediction:  Toronto Defiant
#
# San Francisco Shock vs Toronto Defiant
# =========================
# Random Forest Prediction:  San Francisco Shock
#
# Logistic Regression Prediction:  San Francisco Shock
#
# K Nearest Neighbors Prediction:  San Francisco Shock
#
# SVC Prediction:  Toronto Defiant
#
# Seoul Dynasty vs Toronto Defiant
# =========================
# Random Forest Prediction:  Seoul Dynasty
#
# Logistic Regression Prediction:  Seoul Dynasty
#
# K Nearest Neighbors Prediction:  Seoul Dynasty
#
# SVC Prediction:  Toronto Defiant
#
# Shanghai Dragons vs Toronto Defiant
# =========================
# Random Forest Prediction:  Shanghai Dragons
#
# Logistic Regression Prediction:  Shanghai Dragons
#
# K Nearest Neighbors Prediction:  Shanghai Dragons
#
# SVC Prediction:  Toronto Defiant
#
# Toronto Defiant vs Toronto Defiant
# =========================
# Random Forest Prediction:  Toronto Defiant
#
# Logistic Regression Prediction:  Toronto Defiant
#
# K Nearest Neighbors Prediction:  Toronto Defiant
#
# SVC Prediction:  Toronto Defiant
#
# Vancouver Titans vs Toronto Defiant
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Toronto Defiant
#
# Washington Justice vs Toronto Defiant
# =========================
# Random Forest Prediction:  Toronto Defiant
#
# Logistic Regression Prediction:  Washington Justice
#
# K Nearest Neighbors Prediction:  Washington Justice
#
# SVC Prediction:  Toronto Defiant
#
# Atlanta Reign vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Vancouver Titans
#
# Boston Uprising vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Vancouver Titans
#
# Chengdu Hunters vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Chengdu Hunters
#
# SVC Prediction:  Vancouver Titans
#
# Dallas Fuel vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Vancouver Titans
#
# Florida Mayhem vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Vancouver Titans
#
# Guangzhou Charge vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Guangzhou Charge
#
# SVC Prediction:  Vancouver Titans
#
# Hangzhou Spark vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Vancouver Titans
#
# Houston Outlaws vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Vancouver Titans
#
# London Spitfire vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Vancouver Titans
#
# Los Angeles Gladiators vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Vancouver Titans
#
# Los Angeles Valiant vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Vancouver Titans
#
# New York Excelsior vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  New York Excelsior
#
# SVC Prediction:  Vancouver Titans
#
# Paris Eternal vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Vancouver Titans
#
# Philadelphia Fusion vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Vancouver Titans
#
# San Francisco Shock vs Vancouver Titans
# =========================
# Random Forest Prediction:  San Francisco Shock
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  San Francisco Shock
#
# SVC Prediction:  Vancouver Titans
#
# Seoul Dynasty vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Vancouver Titans
#
# Shanghai Dragons vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Vancouver Titans
#
# Toronto Defiant vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Vancouver Titans
#
# Vancouver Titans vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Vancouver Titans
#
# Washington Justice vs Vancouver Titans
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Vancouver Titans
#
# Atlanta Reign vs Washington Justice
# =========================
# Random Forest Prediction:  Atlanta Reign
#
# Logistic Regression Prediction:  Atlanta Reign
#
# K Nearest Neighbors Prediction:  Atlanta Reign
#
# SVC Prediction:  Washington Justice
#
# Boston Uprising vs Washington Justice
# =========================
# Random Forest Prediction:  Washington Justice
#
# Logistic Regression Prediction:  Washington Justice
#
# K Nearest Neighbors Prediction:  Boston Uprising
#
# SVC Prediction:  Washington Justice
#
# Chengdu Hunters vs Washington Justice
# =========================
# Random Forest Prediction:  Chengdu Hunters
#
# Logistic Regression Prediction:  Washington Justice
#
# K Nearest Neighbors Prediction:  Chengdu Hunters
#
# SVC Prediction:  Washington Justice
#
# Dallas Fuel vs Washington Justice
# =========================
# Random Forest Prediction:  Washington Justice
#
# Logistic Regression Prediction:  Washington Justice
#
# K Nearest Neighbors Prediction:  Washington Justice
#
# SVC Prediction:  Washington Justice
#
# Florida Mayhem vs Washington Justice
# =========================
# Random Forest Prediction:  Washington Justice
#
# Logistic Regression Prediction:  Washington Justice
#
# K Nearest Neighbors Prediction:  Florida Mayhem
#
# SVC Prediction:  Washington Justice
#
# Guangzhou Charge vs Washington Justice
# =========================
# Random Forest Prediction:  Guangzhou Charge
#
# Logistic Regression Prediction:  Washington Justice
#
# K Nearest Neighbors Prediction:  Guangzhou Charge
#
# SVC Prediction:  Washington Justice
#
# Hangzhou Spark vs Washington Justice
# =========================
# Random Forest Prediction:  Washington Justice
#
# Logistic Regression Prediction:  Hangzhou Spark
#
# K Nearest Neighbors Prediction:  Hangzhou Spark
#
# SVC Prediction:  Washington Justice
#
# Houston Outlaws vs Washington Justice
# =========================
# Random Forest Prediction:  Washington Justice
#
# Logistic Regression Prediction:  Washington Justice
#
# K Nearest Neighbors Prediction:  Washington Justice
#
# SVC Prediction:  Washington Justice
#
# London Spitfire vs Washington Justice
# =========================
# Random Forest Prediction:  Washington Justice
#
# Logistic Regression Prediction:  Washington Justice
#
# K Nearest Neighbors Prediction:  London Spitfire
#
# SVC Prediction:  Washington Justice
#
# Los Angeles Gladiators vs Washington Justice
# =========================
# Random Forest Prediction:  Los Angeles Gladiators
#
# Logistic Regression Prediction:  Washington Justice
#
# K Nearest Neighbors Prediction:  Los Angeles Gladiators
#
# SVC Prediction:  Washington Justice
#
# Los Angeles Valiant vs Washington Justice
# =========================
# Random Forest Prediction:  Washington Justice
#
# Logistic Regression Prediction:  Los Angeles Valiant
#
# K Nearest Neighbors Prediction:  Los Angeles Valiant
#
# SVC Prediction:  Washington Justice
#
# New York Excelsior vs Washington Justice
# =========================
# Random Forest Prediction:  New York Excelsior
#
# Logistic Regression Prediction:  New York Excelsior
#
# K Nearest Neighbors Prediction:  New York Excelsior
#
# SVC Prediction:  Washington Justice
#
# Paris Eternal vs Washington Justice
# =========================
# Random Forest Prediction:  Washington Justice
#
# Logistic Regression Prediction:  Washington Justice
#
# K Nearest Neighbors Prediction:  Paris Eternal
#
# SVC Prediction:  Washington Justice
#
# Philadelphia Fusion vs Washington Justice
# =========================
# Random Forest Prediction:  Washington Justice
#
# Logistic Regression Prediction:  Washington Justice
#
# K Nearest Neighbors Prediction:  Washington Justice
#
# SVC Prediction:  Washington Justice
#
# San Francisco Shock vs Washington Justice
# =========================
# Random Forest Prediction:  San Francisco Shock
#
# Logistic Regression Prediction:  San Francisco Shock
#
# K Nearest Neighbors Prediction:  San Francisco Shock
#
# SVC Prediction:  Washington Justice
#
# Seoul Dynasty vs Washington Justice
# =========================
# Random Forest Prediction:  Seoul Dynasty
#
# Logistic Regression Prediction:  Washington Justice
#
# K Nearest Neighbors Prediction:  Seoul Dynasty
#
# SVC Prediction:  Washington Justice
#
# Shanghai Dragons vs Washington Justice
# =========================
# Random Forest Prediction:  Shanghai Dragons
#
# Logistic Regression Prediction:  Shanghai Dragons
#
# K Nearest Neighbors Prediction:  Shanghai Dragons
#
# SVC Prediction:  Washington Justice
#
# Toronto Defiant vs Washington Justice
# =========================
# Random Forest Prediction:  Washington Justice
#
# Logistic Regression Prediction:  Washington Justice
#
# K Nearest Neighbors Prediction:  Toronto Defiant
#
# SVC Prediction:  Washington Justice
#
# Vancouver Titans vs Washington Justice
# =========================
# Random Forest Prediction:  Vancouver Titans
#
# Logistic Regression Prediction:  Vancouver Titans
#
# K Nearest Neighbors Prediction:  Vancouver Titans
#
# SVC Prediction:  Washington Justice
#
# Washington Justice vs Washington Justice
# =========================
# Random Forest Prediction:  Washington Justice
#
# Logistic Regression Prediction:  Washington Justice
#
# K Nearest Neighbors Prediction:  Washington Justice
#
# SVC Prediction:  Washington Justice

# %%
#listing features for Random Forest
pd.DataFrame(list(zip(rfc.feature_importances_, X_train.columns)), columns = ['Feature Importance','Feature']
            ).sort_values('Feature Importance',ascending = False)
# Out:
#     Feature Importance                                   Feature
# 14            0.036052   Away Average Hybrid Points Differential
# 35            0.033427            Home Average Hybrid True Win %
# 25            0.032583           Home Average Assault True Win %
# 9             0.031289  Away Average Control Points Differential
# 10            0.029798           Away Average Control True Win %
# 11            0.029148      Away Average Control Map Potential %
# 24            0.028773  Home Average Assault Points Differential
# 7             0.028653        Away Average Control Points Earned
# 8             0.027940          Away Average Control Points Lost
# 33            0.026503           Home Average Hybrid Points Lost
# 21            0.026208       Away Average Escort Map Potential %
# 41            0.026046       Home Average Escort Map Potential %
# 6             0.025832      Away Average Assault Map Potential %
# 39            0.025219   Home Average Escort Points Differential
# 36            0.024758       Home Average Hybrid Map Potential %
# 26            0.024551      Home Average Assault Map Potential %
# 40            0.024462            Home Average Escort True Win %
# 13            0.024230           Away Average Hybrid Points Lost
# 3             0.023489          Away Average Assault Points Lost
# 23            0.023378          Home Average Assault Points Lost
# 15            0.022791            Away Average Hybrid True Win %
# 34            0.022713   Home Average Hybrid Points Differential
# 37            0.022050         Home Average Escort Points Earned
# 19            0.021986   Away Average Escort Points Differential
# 17            0.021688         Away Average Escort Points Earned
# 4             0.021604  Away Average Assault Points Differential
# 5             0.021513           Away Average Assault True Win %
# 12            0.021305         Away Average Hybrid Points Earned
# 38            0.021299           Home Average Escort Points Lost
# 31            0.021154      Home Average Control Map Potential %
# 27            0.021032        Home Average Control Points Earned
# 20            0.020849            Away Average Escort True Win %
# 30            0.020757           Home Average Control True Win %
# 18            0.020643           Away Average Escort Points Lost
# 28            0.020207          Home Average Control Points Lost
# 0             0.019564                                   away id
# 32            0.018363         Home Average Hybrid Points Earned
# 1             0.018287                                   home id
# 16            0.017628       Away Average Hybrid Map Potential %
# 2             0.017617        Away Average Assault Points Earned
# 29            0.017593  Home Average Control Points Differential
# 22            0.017017        Home Average Assault Points Earned
